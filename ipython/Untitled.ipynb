# %%
import tensorflow as tf
# %matplotlib inline

# %%
import numpy as np
x_data=np.float32(np.random.rand(2,200))
y_data=np.dot([0.1,0.2],x_data)+0.3

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=Axes3D(fig)
ax.plot_surface(xx, yy, y, rstride=1, cstride=1, cmap='rainbow')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8874a0b63dae> in <module>()
#       3 fig=plt.figure()
#       4 ax=Axes3D(fig)
# ----> 5 ax.plot_surface(xx, yy, y, rstride=1, cstride=1, cmap='rainbow')
#       6 plt.show()
#
# /usr/local/Cellar/python/2.7.13_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1713
#    1714         self.add_collection(polyc)
# -> 1715         self.auto_scale_xyz(X, Y, Z, had_data)
#    1716
#    1717         return polyc
#
# /usr/local/Cellar/python/2.7.13_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in auto_scale_xyz(self, X, Y, Z, had_data)
#     473         self.xy_dataLim.update_from_data_xy(np.array([x, y]).T, not had_data)
#     474         if z is not None:
# ...

# %%
xx.shape

# %%
yy.shape

# %%
# %matplotlib inline

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.plot_surface(xx, yy, y_data, rstride=1, cstride=1, cmap='rainbow')
plt.show()
