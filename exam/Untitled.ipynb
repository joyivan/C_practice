# %%
#-*- coding:utf-8 -*-
from docx import Document
from docx.shared import Inches
import docx
import os
print os.getcwd()
import re
import types


import sys
reload(sys)
sys.setdefaultencoding('utf8')
#sys.path.append("/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/docx")
def check_contain_chinese(check_str):
    for ch in check_str.decode('utf-8'):
        if u'\u4e00' <= ch <= u'\u9fff':
            print (ch)
    print ("END")
def split_str(sp_str):
    pattern = re.compile(r'\\t')
    print re.split(pattern,sp_str)

    
    
    
  



file=docx.Document("basicOfComputer.docx")
                
print("段落数:"+str(len(file.paragraphs)))#段落数为13，每个回车隔离一段

total=[]
#输出每一段的内容
qt=''
aa=''
ab=''
ac=''
ad=''
answers=[]
for para in file.paragraphs:
   # print(para.text)
    
    text=para.text
    #patternQ=re.compile(u'[^\u4E00-\u9FA5]')
    patternQ=re.compile(u'[\u4e00-\u9fa5]'|r'^ABCD')
    resultQ=re.match(patternQ,text)
    if resultQ:
        #print resultQ.group()+'TImu'
        
        #print '题目是:'+text
        qt=text
        
    
   # result=re.match
    patternA = re.compile(r'[ABCD]')
  
    resultA=re.match(patternA,text)
    
    if resultA:
        #print resultA.group()+'Daan'
        
        #timu.append(text.split())
        #patternEnd=re.compile(r'^C')
        #resultEnd=re.match(patternEnd,text)
        #if resultEnd:
        #    total.append(timu)
        #print str(timu).decode('utf-8')
    #print(str(timu).decode('unicode-escape'))
        
        if text.startswith('A、') or text.startswith('C、'):
            answers=text.split()
            if len(answers)==2:
                if text.startswith('A、'):
                    
                    aa=answers[0]
                    ab=answers[1]
                if text.startswith('C、'):
                    ac=answers[0]
                    ad=answers[1]
                    total.append([qt,aa,ab,ac,ad])
                    qt=''
                    aa=''
                    ab=''
                    ac=''
                    ad=''
            if len(answers)==4:
                aa=answers[0]
                ab=answers[1]
                ac=answers[2]
                ad=answers[3]
            
                total.append([qt,aa,ab,ac,ad])
                qt=''
                aa=''
                ab=''
                ac=''
                ad=''
           
            
            
    #patternC=re.compile(r'^C')
    #resultC=re.match(patternC,text)
    #if resultC:
    #    total.append(timu)
    #    timu=[]
    print 'close'
    
   
        
   
   # check_contain_chinese(para.text) 

#输出段落编号及段落内容
#for i in range(len(file.paragraphs)):
#    print("第"+str(i)+"段的内容是："+file.paragraphs[i].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-6c1d13c74850> in <module>()
#      46     text=para.text
#      47     #patternQ=re.compile(u'[^\u4E00-\u9FA5]')
# ---> 48     patternQ=re.compile(u'[\u4e00-\u9fa5]'|r'^ABCD')
#      49     resultQ=re.match(patternQ,text)
#      50     if resultQ:
#
# TypeError: unsupported operand type(s) for |: 'unicode' and 'str'

# %%
#-*- coding:utf-8 -*-
import xlwt
from datetime import datetime
os.remove('example.xls')
style0 = xlwt.easyxf('font: name Times New Roman, color-index red, bold on',
    num_format_str='#,##0.00')
style1 = xlwt.easyxf(num_format_str='D-MMM-YY')

wb = xlwt.Workbook()
ws = wb.add_sheet('A Test Sheet')

for i in range(len(total)):
    for j in range(len(total[i])):
        ws.write(i, j,total[i][j], style0)
        

wb.save('example.xls')

# %%
print(str(total).decode('unicode-escape'))
print

# %%
import numpy as np
for i in range(10):
    print i

# %%
len(total)
# Out:
# 1307

# %%
total
# Out:
# [[u'\u4e16\u754c\u4e0a\u9996\u5148\u5b9e\u73b0\u5b58\u50a8\u7a0b\u5e8f\u7684\u7535\u5b50\u6570\u5b57\u8ba1\u7b97\u673a\u662f____\u3002',
#   u'A\u3001ENIAC',
#   u'B\u3001UNIVAC',
#   u'C\u3001EDVAC',
#   u'D\u3001EDSAC'],
#  [u'\u4e16\u754c\u4e0a\u9996\u5148\u5b9e\u73b0\u5b58\u50a8\u7a0b\u5e8f\u7684\u7535\u5b50\u6570\u5b57\u8ba1\u7b97\u673a\u662f____\u3002',
#   u'A\u3001\u67e5\u5c14\u65af.\u5df4\u8d1d\u5947',
#   u'B\u3001\u56fe\u7075',
#   u'C\u3001EDVAC',
#   u'D\u3001EDSAC'],
#  [u'\u4e16\u754c\u4e0a\u9996\u5148\u5b9e\u73b0\u5b58\u50a8\u7a0b\u5e8f\u7684\u7535\u5b50\u6570\u5b57\u8ba1\u7b97\u673a\u662f____\u3002',
#   u'A\u3001\u67e5\u5c14\u65af.\u5df4\u8d1d\u5947',
#   u'B\u3001\u56fe\u7075',
#   u'C\u3001\u963f\u5854\u8bfa\u7d22\u592b',
#   u'D\u3001\u51af.\u8bfa\u4f9d\u66fc'],
#  [u'\u4e16\u754c\u4e0a\u9996\u6b21\u63d0\u51fa\u5b58\u50a8\u7a0b\u5e8f\u8ba1\u7b97\u673a\u4f53\u7cfb\u7ed3\u6784\u7684\u662f____\u3002',
#   u'A\u3001\u827e\u4ed1\u2022\u56fe\u7075',
#   u'B\u3001\u51af\u2022\u8bfa\u4f9d\u66fc',
#   u'C\u3001\u83ab\u5947\u83b1',
#   u'D\u3001\u6bd4\u5c14\u2022\u76d6\u8328'],
#  [u'\u8ba1\u7b97\u673a\u6240\u5177\u6709\u7684\u5b58\u50a8\u7a0b\u5e8f\u548c\u7a0b\u5e8f\u539f\u7406\u662f____\u63d0\u51fa\u7684\u3002',
#   u'A\u3001\u56fe\u7075',
#   u'B\u3001\u5e03\u5c14',
#   u'C\u3001\u51af\u2022\u8bfa\u4f9d\u66fc',
#   u'D\u3001\u7231\u56e0\u65af\u5766'],
#  [u'\u7535\u5b50\u8ba1\u7b97\u673a\u6280\u672f\u5728\u534a\u4e2a\u4e16\u7eaa\u4e2d\u867d\u6709\u5f88\u5927\u8fdb\u6b65\uff0c\u4f46\u81f3\u4eca\u5176\u8fd0\u884c\u4ecd\u9075\u5faa\u7740\u4e00\u4f4d\u79d1\u5b66\u5bb6\u63d0\u51fa\u7684\u57fa\u672c\u539f\u7406\u3002\u4ed6\u5c31\u662f____\u3002',
#   u'A\u3001\u56fe\u7075',
#   u'B\u3001\u5e03\u5c14',
#   u'C\u3001\u51af\u2022\u8bfa\u4f9d\u66fc',
#   u'D\u3001\u7231\u56e0\u65af\u5766'],
#  [u'\u7535\u5b50\u8ba1\u7b97\u673a\u6280\u672f\u5728\u534a\u4e2a\u4e16\u7eaa\u4e2d\u867d\u6709\u5f88\u5927\u8fdb\u6b65\uff0c\u4f46\u81f3\u4eca\u5176\u8fd0\u884c\u4ecd\u9075\u5faa\u7740\u4e00\u4f4d\u79d1\u5b66\u5bb6\u63d0\u51fa\u7684\u57fa\u672c\u539f\u7406\u3002\u4ed6\u5c31\u662f____\u3002',
#   u'A\u3001\u5916\u578b\u7ed3\u6784',
#   u'B\u3001\u603b\u7ebf\u7ed3\u6784',
#   u'C\u3001\u5b58\u53d6\u7ed3\u6784',
#   u'D\u3001\u4f53\u7cfb\u7ed3\u6784'],
#  [u'\u8fc7\u7a0b\u63a7\u5236    B\u3001\u79d1\u5b66\u8ba1\u7b97   C\u3001\u6570\u636e\u5904\u7406   D\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u7cfb\u7edf',
#   u'A\u3001\u5916\u578b\u7ed3\u6784',
#   u'B\u3001\u603b\u7ebf\u7ed3\u6784',
#   u'C\u3001\u5b58\u53d6\u7ed3\u6784',
#   u'D\u3001\u4f53\u7cfb\u7ed3\u6784'],
#  [u'\u8fc7\u7a0b\u63a7\u5236    B\u3001\u79d1\u5b66\u8ba1\u7b97   C\u3001\u6570\u636e\u5904\u7406   D\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u7cfb\u7edf',
#   u'A\u3001\u5916\u578b\u7ed3\u6784',
#   u'B\u3001\u603b\u7ebf\u7ed3\u6784',
#   u'C\u3001\u5b58\u53d6\u7ed3\u6784',
#   u'D\u3001\u4f53\u7cfb\u7ed3\u6784'],
#  [u'\u4ee5\u4e0b\u5c5e\u4e8e\u7b2c\u56db\u4ee3\u5fae\u5904\u7406\u5668\u7684\u662f____\u3002',
#   u'A\u3001Intel8008',
#   u'B\u3001Intel8085',
#   u'C\u3001\u5b58\u53d6\u7ed3\u6784',
#   u'D\u3001\u4f53\u7cfb\u7ed3\u6784'],
#  [u'\u4ee5\u4e0b\u5c5e\u4e8e\u7b2c\u56db\u4ee3\u5fae\u5904\u7406\u5668\u7684\u662f____\u3002',
#   u'A\u3001Intel8008',
#   u'B\u3001Intel8085',
#   u'C\u3001Intel8086',
#   u'D\u3001Intel80386/486/586'],
#  [u'\u4ee5\u4e0b\u5c5e\u4e8e\u7b2c\u56db\u4ee3\u5fae\u5904\u7406\u5668\u7684\u662f____\u3002',
#   u'A\u3001\u7b2c\u4e00\u4ee3',
#   u'B\u3001\u7b2c\u4e09\u4ee3',
#   u'C\u3001Intel8086',
#   u'D\u3001Intel80386/486/586'],
#  [u'\u4ee5\u4e0b\u5c5e\u4e8e\u7b2c\u56db\u4ee3\u5fae\u5904\u7406\u5668\u7684\u662f____\u3002',
#   u'A\u3001\u7b2c\u4e00\u4ee3',
#   u'B\u3001\u7b2c\u4e09\u4ee3',
#   u'C\u3001\u7b2c\u56db\u4ee3',
#   u'D\u3001\u7b2c\u4e94\u4ee3'],
#  [u'\u8ba1\u7b97\u673a\u80fd\u591f\u81ea\u52a8\u3001\u51c6\u786e\u3001\u5feb\u901f\u5730\u6309\u7167\u4eba\u4eec\u7684\u610f\u56fe\u8fdb\u884c\u8fd0\u884c\u7684\u6700\u57fa\u672c\u601d\u60f3\u662f____\u3002',
#   u'A\u3001\u91c7\u7528\u8d85\u5927\u89c4\u6a21\u96c6\u6210\u7535\u8def',
#   u'B\u3001\u91c7\u7528CPU\u4f5c\u4e3a\u4e2d\u592e\u6838\u5fc3\u90e8\u4ef6',
#   u'C\u3001\u7b2c\u56db\u4ee3',
#   u'D\u3001\u7b2c\u4e94\u4ee3'],
#  [u'\u8ba1\u7b97\u673a\u80fd\u591f\u81ea\u52a8\u3001\u51c6\u786e\u3001\u5feb\u901f\u5730\u6309\u7167\u4eba\u4eec\u7684\u610f\u56fe\u8fdb\u884c\u8fd0\u884c\u7684\u6700\u57fa\u672c\u601d\u60f3\u662f____\u3002',
#   u'A\u3001\u91c7\u7528\u8d85\u5927\u89c4\u6a21\u96c6\u6210\u7535\u8def',
#   u'B\u3001\u91c7\u7528CPU\u4f5c\u4e3a\u4e2d\u592e\u6838\u5fc3\u90e8\u4ef6',
#   u'C\u3001\u91c7\u7528\u64cd\u4f5c\u7cfb\u7edf',
#   u'D\u3001\u5b58\u50a8\u7a0b\u5e8f\u548c\u7a0b\u5e8f\u63a7\u5236'],
#  [u'\u8ba1\u7b97\u673a\u5de5\u4f5c\u6700\u91cd\u8981\u7684\u7279\u5f81\u662f____\u3002 ',
#   u'A\u3001\u9ad8\u901f\u5ea6',
#   u'B\u3001\u9ad8\u7cbe\u5ea6',
#   u'C\u3001\u91c7\u7528\u64cd\u4f5c\u7cfb\u7edf',
#   u'D\u3001\u5b58\u50a8\u7a0b\u5e8f\u548c\u7a0b\u5e8f\u63a7\u5236'],
#  [u'\u8ba1\u7b97\u673a\u5de5\u4f5c\u6700\u91cd\u8981\u7684\u7279\u5f81\u662f____\u3002 ',
#   u'A\u3001\u9ad8\u901f\u5ea6',
#   u'B\u3001\u9ad8\u7cbe\u5ea6',
#   u'C\u3001\u5b58\u50a8\u7a0b\u5e8f\u548c\u7a0b\u5e8f\u63a7\u5236',
#   u'D\u3001\u8bb0\u5fc6\u529b\u5f3a'],
#  [u'\u8ba1\u7b97\u673a\u4e1a\u754c\u6700\u521d\u7684\u786c\u4ef6\u5de8\u5934\u201c\u84dd\u8272\u5de8\u4eba\u201d\u6307\u7684\u662f____\u3002',
#   u'A\u3001IBM',
#   u'B\u3001Microsoft',
#   u'C\u3001\u8054\u60f3',
#   u'D\u3001Sun'],
#  [u'\u7b2c\u56db\u5a92\u4f53\u662f\u6307\uff08     \u3000 \uff09\u3002',
#   u'A\u3001\u62a5\u7eb8\u5a92\u4f53',
#   u'B\u3001\u7f51\u7edc\u5a92\u4f53',
#   u'C\u3001\u7535\u89c6\u5a92\u4f53',
#   u'D\u3001\u5e7f\u64ad\u5a92\u4f53'],
#  [u'\u7b2c\u56db\u5a92\u4f53\u662f\u6307\uff08     \u3000 \uff09\u3002',
#   u'A\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u6559\u80b2',
#   u'B\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u6d4b\u8bd5',
#   u'C\u3001\u7535\u89c6\u5a92\u4f53',
#   u'D\u3001\u5e7f\u64ad\u5a92\u4f53'],
#  [u'\u7b2c\u56db\u5a92\u4f53\u662f\u6307\uff08     \u3000 \uff09\u3002',
#   u'A\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u6559\u80b2',
#   u'B\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u6d4b\u8bd5',
#   u'C\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u8bbe\u8ba1',
#   u'D\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u7ba1\u7406'],
#  [u'\u7b2c\u56db\u5a92\u4f53\u662f\u6307\uff08     \u3000 \uff09\u3002',
#   u'A\u3001\u5236\u9020',
#   u'B\u3001\u8bbe\u8ba1',
#   u'C\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u8bbe\u8ba1',
#   u'D\u3001\u8ba1\u7b97\u673a\u8f85\u52a9\u7ba1\u7406'],
#  [u'\u7b2c\u56db\u5a92\u4f53\u662f\u6307\uff08     \u3000 \uff09\u3002',
#   u'A\u3001\u5236\u9020',
#   u'B\u3001\u8bbe\u8ba1',
#   u'C\u3001\u6d4b\u8bd5',
#   u'D\u3001\u6559\u5b66'],
#  [u'\u5c06\u9ad8\u7ea7\u8bed\u8a00\u7a0b\u5e8f\u8bbe\u8ba1\u8bed\u8a00\u6e90\u7a0b\u5e8f\u7ffb\u8bd1\u6210\u8ba1\u7b97\u673a\u53ef\u6267\u884c\u4ee3\u7801\u7684\u8f6f\u4ef6\u79f0\u4e3a ____',
#   u'A\u3001\u6c47\u7f16\u7a0b\u5e8f',
#   u'B\u3001\u7f16\u8bd1\u7a0b\u5e8f',
#   u'C\u3001\u7ba1\u7406\u7a0b\u5e8f',
#   u'D\u3001\u670d\u52a1\u7a0b\u5e8f'],
#  [u'\u8ba1\u7b97\u673a\u4e4b\u6240\u4ee5\u80fd\u5b9e\u73b0\u81ea\u52a8\u8fde\u7eed\u8fd0\u7b97\uff0c\u662f\u7531\u4e8e\u91c7\u7528\u4e86_____\u539f\u7406\u3002 ',
#   u'A\u3001\u5e03\u5c14\u903b\u8f91',
#   u'B\u3001\u5b58\u50a8\u7a0b\u5e8f',
#   u'C\u3001\u7ba1\u7406\u7a0b\u5e8f',
#   u'D\u3001\u670d\u52a1\u7a0b\u5e8f'],
#  [u'\u8ba1\u7b97\u673a\u4e4b\u6240\u4ee5\u80fd\u5b9e\u73b0\u81ea\u52a8\u8fde\u7eed\u8fd0\u7b97\uff0c\u662f\u7531\u4e8e\u91c7\u7528\u4e86_____\u539f\u7406\u3002 ',
#   u'A\u3001\u5e03\u5c14\u903b\u8f91',
#   u'B\u3001\u5b58\u50a8\u7a0b\u5e8f',
#   u'C\u3001\u6570\u5b57\u7535\u8def',
#   u'D\u3001\u96c6\u6210\u7535\u8def'],
#  [u'\u67d0\u5355\u4f4d\u81ea\u884c\u5f00\u53d1\u7684\u5de5\u8d44\u7ba1\u7406\u7cfb\u7edf\uff0c\u6309\u8ba1\u7b97\u673a\u5e94\u7528\u7684\u7c7b\u578b\u5212\u5206\uff0c\u5b83\u5c5e\u4e8e____\u3002',
#   u'A\u3001\u79d1\u5b66\u8ba1\u7b97',
#   u'B\u3001\u8f85\u52a9\u8bbe\u8ba1',
#   u'C\u3001\u6570\u5b57\u7535\u8def',
#   u'D\u3001\u96c6\u6210\u7535\u8def'],
#  [u'\u67d0\u5355\u4f4d\u81ea\u884c\u5f00\u53d1\u7684\u5de5\u8d44\u7ba1\u7406\u7cfb\u7edf\uff0c\u6309\u8ba1\u7b97\u673a\u5e94\u7528\u7684\u7c7b\u578b\u5212\u5206\uff0c\u5b83\u5c5e\u4e8e____\u3002',
#   u'A\u3001\u79d1\u5b66\u8ba1\u7b97',
#   u'B\u3001\u8f85\u52a9\u8bbe\u8ba1',
#   u'C\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u5b9e\u65f6\u63a7\u5236'],
#  [u'\u7528\u8ba1\u7b97\u673a\u8fdb\u884c\u8d44\u6599\u68c0\u7d22\u5de5\u4f5c\uff0c\u662f\u5c5e\u4e8e\u8ba1\u7b97\u673a\u5e94\u7528\u4e2d\u7684____\u3002',
#   u'A\u3001\u79d1\u5b66\u8ba1\u7b97',
#   u'B\u3001\u6570\u636e\u5904\u7406',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236',
#   u'D\u3001\u4eba\u5de5\u667a\u80fd'],
#  [u'\u7ed3\u6784\u5316\u7a0b\u5e8f\u8bbe\u8ba1\u7684\u4e09\u79cd\u57fa\u672c\u63a7\u5236\u7ed3\u6784\u662f____\u3002',
#   u'A\u3001\u987a\u5e8f\u3001\u9009\u62e9\u548c\u8f6c\u5411',
#   u'B\u3001\u5c42\u6b21\u3001\u7f51\u72b6\u548c\u5faa\u73af',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236',
#   u'D\u3001\u4eba\u5de5\u667a\u80fd'],
#  [u'\u7ed3\u6784\u5316\u7a0b\u5e8f\u8bbe\u8ba1\u7684\u4e09\u79cd\u57fa\u672c\u63a7\u5236\u7ed3\u6784\u662f____\u3002',
#   u'A\u3001\u987a\u5e8f\u3001\u9009\u62e9\u548c\u8f6c\u5411',
#   u'B\u3001\u5c42\u6b21\u3001\u7f51\u72b6\u548c\u5faa\u73af',
#   u'C\u3001\u6a21\u5757\u3001\u9009\u62e9\u548c\u5faa\u73af',
#   u'D\u3001\u987a\u5e8f\u3001\u5faa\u73af\u548c\u9009\u62e9'],
#  [u'\u76ee\u524d\u8ba1\u7b97\u673a\u5e94\u7528\u9886\u57df\u53ef\u5927\u81f4\u5206\u4e3a\u4e09\u4e2a\u65b9\u9762\uff0c\u6307\u51fa\u4e0b\u5217\u6b63\u786e\u7b54\u6848____\u3002',
#   u'A\u3001CAI\u3001\u4e13\u5bb6\u7cfb\u7edf\u3001\u4eba\u5de5\u667a\u80fd',
#   u'B\u3001\u5de5\u7a0b\u8bbe\u8ba1\u3001CAI\u3001\u6587\u5b57\u5904\u7406',
#   u'C\u3001\u6a21\u5757\u3001\u9009\u62e9\u548c\u5faa\u73af',
#   u'D\u3001\u987a\u5e8f\u3001\u5faa\u73af\u548c\u9009\u62e9'],
#  [u'\u76ee\u524d\u8ba1\u7b97\u673a\u5e94\u7528\u9886\u57df\u53ef\u5927\u81f4\u5206\u4e3a\u4e09\u4e2a\u65b9\u9762\uff0c\u6307\u51fa\u4e0b\u5217\u6b63\u786e\u7b54\u6848____\u3002',
#   u'A\u3001CAI\u3001\u4e13\u5bb6\u7cfb\u7edf\u3001\u4eba\u5de5\u667a\u80fd',
#   u'B\u3001\u5de5\u7a0b\u8bbe\u8ba1\u3001CAI\u3001\u6587\u5b57\u5904\u7406',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236\u3001\u79d1\u5b66\u8ba1\u7b97\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u6570\u636e\u5206\u6790\u3001\u4eba\u5de5\u667a\u80fd\u3001\u8ba1\u7b97\u673a\u7f51\u7edc'],
#  [u'\u4e0b\u9762\u662f\u6709\u5173\u8ba1\u7b97\u673a\u75c5\u6bd2\u7684\u8bf4\u6cd5\uff0c\u5176\u4e2d____\u4e0d\u6b63\u786e',
#   u'A\u3001CAI\u3001\u4e13\u5bb6\u7cfb\u7edf\u3001\u4eba\u5de5\u667a\u80fd',
#   u'B\u3001\u5de5\u7a0b\u8bbe\u8ba1\u3001CAI\u3001\u6587\u5b57\u5904\u7406',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236\u3001\u79d1\u5b66\u8ba1\u7b97\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u6570\u636e\u5206\u6790\u3001\u4eba\u5de5\u667a\u80fd\u3001\u8ba1\u7b97\u673a\u7f51\u7edc'],
#  [u'\u4e0b\u9762\u662f\u6709\u5173\u8ba1\u7b97\u673a\u75c5\u6bd2\u7684\u8bf4\u6cd5\uff0c\u5176\u4e2d____\u4e0d\u6b63\u786e',
#   u'A\u3001CAI\u3001\u4e13\u5bb6\u7cfb\u7edf\u3001\u4eba\u5de5\u667a\u80fd',
#   u'B\u3001\u5de5\u7a0b\u8bbe\u8ba1\u3001CAI\u3001\u6587\u5b57\u5904\u7406',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236\u3001\u79d1\u5b66\u8ba1\u7b97\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u6570\u636e\u5206\u6790\u3001\u4eba\u5de5\u667a\u80fd\u3001\u8ba1\u7b97\u673a\u7f51\u7edc'],
#  [u'\u8ba1\u7b97\u673a\u80fd\u76f4\u63a5\u6267\u884c\u7684\u6307\u4ee4\u5305\u62ec\u4e24\u90e8\u5206\uff0c\u5b83\u4eec\u662f____\u3002 ',
#   u'A\u3001\u6e90\u64cd\u4f5c\u6570\u4e0e\u76ee\u6807\u64cd\u4f5c\u6570',
#   u'B\u3001\u64cd\u4f5c\u7801\u4e0e\u64cd\u4f5c\u6570',
#   u'C\u3001\u5b9e\u65f6\u63a7\u5236\u3001\u79d1\u5b66\u8ba1\u7b97\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u6570\u636e\u5206\u6790\u3001\u4eba\u5de5\u667a\u80fd\u3001\u8ba1\u7b97\u673a\u7f51\u7edc'],
#  [u'\u8ba1\u7b97\u673a\u80fd\u76f4\u63a5\u6267\u884c\u7684\u6307\u4ee4\u5305\u62ec\u4e24\u90e8\u5206\uff0c\u5b83\u4eec\u662f____\u3002 ',
#   u'A\u3001\u6e90\u64cd\u4f5c\u6570\u4e0e\u76ee\u6807\u64cd\u4f5c\u6570',
#   u'B\u3001\u64cd\u4f5c\u7801\u4e0e\u64cd\u4f5c\u6570',
#   u'C\u3001ASCII\u7801\u4e0e\u6c49\u5b57\u4ee3\u7801',
#   u'D\u3001\u6570\u5b57\u4e0e\u5b57\u7b26'],
#  [u'\u4e0d\u540c\u7684\u8ba1\u7b97\u673a\uff0c\u5176\u6307\u4ee4\u7cfb\u7edf\u4e5f\u4e0d\u76f8\u540c\uff0c\u8fd9\u4e3b\u8981\u53d6\u51b3\u4e8e____\u3002',
#   u'A\u3001\u6240\u7528\u7684\u64cd\u4f5c\u7cfb\u7edf',
#   u'B\u3001\u7cfb\u7edf\u7684\u603b\u4f53\u7ed3\u6784',
#   u'C\u3001ASCII\u7801\u4e0e\u6c49\u5b57\u4ee3\u7801',
#   u'D\u3001\u6570\u5b57\u4e0e\u5b57\u7b26'],
#  [u'\u4e0d\u540c\u7684\u8ba1\u7b97\u673a\uff0c\u5176\u6307\u4ee4\u7cfb\u7edf\u4e5f\u4e0d\u76f8\u540c\uff0c\u8fd9\u4e3b\u8981\u53d6\u51b3\u4e8e____\u3002',
#   u'A\u3001\u6240\u7528\u7684\u64cd\u4f5c\u7cfb\u7edf',
#   u'B\u3001\u7cfb\u7edf\u7684\u603b\u4f53\u7ed3\u6784',
#   u'C\u3001\u6240\u7528\u7684CPU',
#   u'D\u3001\u6240\u7528\u7684\u7a0b\u5e8f\u8bbe\u8ba1\u8bed\u8a00'],
#  [u'\u591a\u5a92\u4f53\u8ba1\u7b97\u673a\u662f\u6307____\u3002',
#   u'A\u3001\u5177\u6709\u591a\u79cd\u5916\u90e8\u8bbe\u5907\u7684\u8ba1\u7b97\u673a',
#   u'B\u3001\u80fd\u4e0e\u591a\u79cd\u7535\u5668\u8fde\u63a5\u7684\u8ba1\u7b97\u673a',
#   u'C\u3001\u6240\u7528\u7684CPU',
#   u'D\u3001\u6240\u7528\u7684\u7a0b\u5e8f\u8bbe\u8ba1\u8bed\u8a00'],
#  [u'\u591a\u5a92\u4f53\u8ba1\u7b97\u673a\u662f\u6307____\u3002',
#   u'A\u3001\u5177\u6709\u591a\u79cd\u5916\u90e8\u8bbe\u5907\u7684\u8ba1\u7b97\u673a',
#   u'B\u3001\u80fd\u4e0e\u591a\u79cd\u7535\u5668\u8fde\u63a5\u7684\u8ba1\u7b97\u673a',
#   u'C\u3001\u80fd\u5904\u7406\u591a\u79cd\u5a92\u4f53\u7684\u8ba1\u7b97\u673a',
#   u'D\u3001\u501f\u52a9\u591a\u79cd\u5a92\u4f53\u64cd\u4f5c\u7684\u8ba1\u7b97\u673a'],
#  [u'\u8ba1\u7b97\u673a\u7528\u4e8e\u89e3\u51b3\u79d1\u5b66\u7814\u7a76\u4e0e\u5de5\u7a0b\u8ba1\u7b97\u4e2d\u7684\u6570\u5b66\u95ee\u9898\uff0c\u79f0\u4e3a____\u3002',
#   u'A\u3001\u6570\u503c\u8ba1\u7b97',
#   u'B\u3001\u6570\u5b66\u5efa\u6a21',
#   u'C\u3001\u6570\u636e\u5904\u7406',
#   u'D\u3001\u81ea\u52a8\u63a7\u5236\ue003'],
#  [u'\u8ba1\u7b97\u673a\u7528\u4e8e\u89e3\u51b3\u79d1\u5b66\u7814\u7a76\u4e0e\u5de5\u7a0b\u8ba1\u7b97\u4e2d\u7684\u6570\u5b66\u95ee\u9898\uff0c\u79f0\u4e3a____\u3002',
#   u'A\u3001\u5de5\u7a0b\u8ba1\u7b97',
#   u'B\u3001\u6570\u636e\u5904\u7406',
#   u'C\u3001\u81ea\u52a8\u63a7\u5236',
#   u'D\u3001\u5b9e\u65f6\u63a7\u5236'],
#  [u'\u8ba1\u7b97\u673a\u4e2d\u7684\u6240\u6709\u4fe1\u606f\u90fd\u662f\u4ee5____\u7684\u5f62\u5f0f\u5b58\u50a8\u5728\u673a\u5668\u5185\u90e8\u7684\u3002 ',
#   u'A\u3001\u5b57\u7b26',
#   u'B\u3001\u4e8c\u8fdb\u5236\u7f16\u7801',
#   u'C\u3001BCD\u7801',
#   u'D\u3001ASCII\u7801'],
#  [u'\u5728\u8ba1\u7b97\u673a\u5185\uff0c\u591a\u5a92\u4f53\u6570\u636e\u6700\u7ec8\u662f\u4ee5_____\u5f62\u5f0f\u5b58\u5728\u7684\u3002',
#   u'A\u3001\u4e8c\u8fdb\u5236\u4ee3\u7801',
#   u'B\u3001\u7279\u6b8a\u7684\u538b\u7f29\u7801',
#   u'C\u3001\u6a21\u62df\u6570\u636e',
#   u'D\u3001\u56fe\u5f62'],
#  [u'\u5728\u5fae\u673a\u4e2d\uff0cbit \u7684\u4e2d\u6587\u542b\u4e49\u662f____\u3002',
#   u'A\u3001\u4e8c\u8fdb\u5236\u4f4d',
#   u'B\u3001\u53cc\u5b57',
#   u'C\u3001\u5b57\u8282',
#   u'D\u3001\u5b57'],
#  [u'\u7528\u4e00\u4e2a\u5b57\u8282\u6700\u591a\u80fd\u7f16\u51fa____\u4e0d\u540c\u7684\u7801\u3002',
#   u'A\u30018\u4e2a',
#   u'B\u300116\u4e2a',
#   u'C\u3001128\u4e2a',
#   u'D\u3001256\u4e2a'],
#  [u'\u8ba1\u7b97\u673a\u5b58\u50a8\u548c\u5904\u7406\u6570\u636e\u7684\u57fa\u672c\u5355\u4f4d\u662f____\u3002',
#   u'A\u3001bit',
#   u'B\u3001Byte',
#   u'C\u3001GB',
#   u'D\u3001KB'],
#  [u'\u8ba1\u7b97\u673a\u5b58\u50a8\u548c\u5904\u7406\u6570\u636e\u7684\u57fa\u672c\u5355\u4f4d\u662f____\u3002',
#   u'A\u30011',
#   u'B\u30014',
#   u'C\u30018',
#   u'D\u300110'],
#  [u'\u5728\u63cf\u8ff0\u4fe1\u606f\u4f20\u8f93\u4e2dbps\u8868\u793a\u7684\u662f____\u3002 ',
#   u'A\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u5b57\u8282\u6570',
#   u'B\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u6307\u4ee4\u6570',
#   u'C\u30018',
#   u'D\u300110'],
#  [u'\u5728\u63cf\u8ff0\u4fe1\u606f\u4f20\u8f93\u4e2dbps\u8868\u793a\u7684\u662f____\u3002 ',
#   u'A\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u5b57\u8282\u6570',
#   u'B\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u6307\u4ee4\u6570',
#   u'C\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u5b57\u6570',
#   u'D\u3001\u6bcf\u79d2\u4f20\u8f93\u7684\u4f4d\u6570'],
#  [u'\u5728\u63cf\u8ff0\u4fe1\u606f\u4f20\u8f93\u4e2dbps\u8868\u793a\u7684\u662f____\u3002 ',
#   u'A\u3001\u5fae\u673a\u578b\u53f7',
#   u'B\u3001\u5185\u5b58\u5bb9\u91cf',
#   u'C\u3001\u5b58\u50a8\u5355\u4f4d',
#   u'D\u3001\u673a\u5668\u5b57\u957f'],
#  [u'\u5fae\u5904\u7406\u5668\u5904\u7406\u7684\u6570\u636e\u57fa\u672c\u5355\u4f4d\u4e3a\u5b57\u3002\u4e00\u4e2a\u5b57\u7684\u957f\u5ea6\u901a\u5e38\u662f____\u3002',
#   u'A\u300116\u4e2a\u4e8c\u8fdb\u5236\u4f4d',
#   u'B\u300132\u4e2a\u4e8c\u8fdb\u5236\u4f4d',
#   u'C\u3001\u5b58\u50a8\u5355\u4f4d',
#   u'D\u3001\u673a\u5668\u5b57\u957f'],
#  [u'\u5fae\u5904\u7406\u5668\u5904\u7406\u7684\u6570\u636e\u57fa\u672c\u5355\u4f4d\u4e3a\u5b57\u3002\u4e00\u4e2a\u5b57\u7684\u957f\u5ea6\u901a\u5e38\u662f____\u3002',
#   u'A\u300116\u4e2a\u4e8c\u8fdb\u5236\u4f4d',
#   u'B\u300132\u4e2a\u4e8c\u8fdb\u5236\u4f4d',
#   u'C\u300164\u4e2a\u4e8c\u8fdb\u5236\u4f4d',
#   u'D\u3001\u4e0e\u5fae\u5904\u7406\u5668\u82af\u7247\u7684\u578b\u53f7\u6709\u5173'],
#  [u'\u5b57\u7b26\u4e32\u201cIBM\u201d\u4e2d\u7684\u5b57\u6bcdB\u5b58\u653e\u5728\u8ba1\u7b97\u673a\u5185\u5360\u7528\u7684\u4e8c\u8fdb\u5236\u4f4d\u4e2a\u6570\u662f____\u3002',
#   u'A\u30018',
#   u'B\u30014',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u82e5\u4e00\u53f0\u8ba1\u7b97\u673a\u7684\u5b57\u957f\u4e3a4\u4e2a\u5b57\u8282\uff0c\u8fd9\u610f\u5473\u7740\u5b83____\u3002',
#   u'A\u30018',
#   u'B\u30014',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u82e5\u4e00\u53f0\u8ba1\u7b97\u673a\u7684\u5b57\u957f\u4e3a4\u4e2a\u5b57\u8282\uff0c\u8fd9\u610f\u5473\u7740\u5b83____\u3002',
#   u'A\u30018',
#   u'B\u30014',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u82e5\u4e00\u53f0\u8ba1\u7b97\u673a\u7684\u5b57\u957f\u4e3a4\u4e2a\u5b57\u8282\uff0c\u8fd9\u610f\u5473\u7740\u5b83____\u3002',
#   u'A\u30018',
#   u'B\u30014',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u82e5\u4e00\u53f0\u8ba1\u7b97\u673a\u7684\u5b57\u957f\u4e3a4\u4e2a\u5b57\u8282\uff0c\u8fd9\u610f\u5473\u7740\u5b83____\u3002',
#   u'A\u30018',
#   u'B\u30014',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u5bf9PC\u673a\uff0c\u4eba\u4eec\u5e38\u63d0\u5230\u7684"Pentium"\u3001"Pentium IV"\u6307\u7684\u662f_____\u3002',
#   u'A\u3001\u5b58\u50a8\u5668',
#   u'B\u3001\u5185\u5b58\u54c1\u724c',
#   u'C\u30012',
#   u'D\u30011'],
#  [u'\u5bf9PC\u673a\uff0c\u4eba\u4eec\u5e38\u63d0\u5230\u7684"Pentium"\u3001"Pentium IV"\u6307\u7684\u662f_____\u3002',
#   u'A\u3001\u5b58\u50a8\u5668',
#   u'B\u3001\u5185\u5b58\u54c1\u724c',
#   u'C\u3001\u4e3b\u677f\u578b\u53f7',
#   u'D\u3001CPU\u7c7b\u578b'],
#  [u'\u4eba\u4eec\u901a\u5e38\u8bf4\u7684\u6269\u8ba1\u7b97\u673a\u7684\u5185\u5b58\uff0c\u6307\u7684\u662f____\u3002',
#   u'A\u3001ROM',
#   u'B\u3001CMOS',
#   u'C\u3001CPU',
#   u'D\u3001RAM'],
#  [u'\u8fde\u5230\u5c40\u57df\u7f51\u4e0a\u7684\u8282\u70b9\u8ba1\u7b97\u673a\u5fc5\u9700\u8981\u5b89\u88c5____\u786c\u4ef6\u3002',
#   u'A\u3001\u8c03\u5236\u89e3\u8c03\u5668',
#   u'B\u3001\u4ea4\u6362\u673a',
#   u'C\u3001\u96c6\u7ebf\u5668',
#   u'D\u3001\u7f51\u7edc\u9002\u914d\u5361'],
#  [u'\u8ba1\u7b97\u673a\u7684\u4e09\u7c7b\u603b\u7ebf\u4e2d\uff0c\u4e0d\u5305\u62ec____\u3002',
#   u'A\u3001\u63a7\u5236\u603b\u7ebf',
#   u'B\u3001\u5730\u5740\u603b\u7ebf',
#   u'C\u3001\u4f20\u8f93\u603b\u7ebf',
#   u'D\u3001\u6570\u636e\u603b\u7ebf'],
#  [u'\u5173\u4e8e\u8ba1\u7b97\u673a\u603b\u7ebf\u7684\u8bf4\u660e\u4e0d\u6b63\u786e\u7684\u662f____\u3002',
#   u'A\u3001\u63a7\u5236\u603b\u7ebf',
#   u'B\u3001\u5730\u5740\u603b\u7ebf',
#   u'C\u3001\u4f20\u8f93\u603b\u7ebf',
#   u'D\u3001\u6570\u636e\u603b\u7ebf'],
#  [u'\u5173\u4e8e\u8ba1\u7b97\u673a\u603b\u7ebf\u7684\u8bf4\u660e\u4e0d\u6b63\u786e\u7684\u662f____\u3002',
#   u'A\u3001\u63a7\u5236\u603b\u7ebf',
#   u'B\u3001\u5730\u5740\u603b\u7ebf',
#   u'C\u3001\u4f20\u8f93\u603b\u7ebf',
#   u'D\u3001\u6570\u636e\u603b\u7ebf'],
#  [u'\u8ba1\u7b97\u673a\u4e2d\u5b58\u50a8\u4fe1\u606f\u7684\u6700\u5c0f\u5355\u4f4d\u662f____\u3002',
#   u'A\u3001\u5b57',
#   u'B\u3001\u5b57\u8282',
#   u'C\u3001\u5b57\u957f',
#   u'D\u3001\u4f4d'],
#  [u'\u5728\u8ba1\u7b97\u673a\u4e2d\u4f7f\u7528\u7684\u952e\u76d8\u662f\u8fde\u63a5\u5728____\u3002',
#   u'A\u3001\u6253\u5370\u673a\u63a5\u53e3\u4e0a\u7684',
#   u'B\u3001\u663e\u793a\u5668\u63a5\u53e3\u4e0a\u7684',
#   u'C\u3001\u5b57\u957f',
#   u'D\u3001\u4f4d'],
#  [u'\u5728\u8ba1\u7b97\u673a\u4e2d\u4f7f\u7528\u7684\u952e\u76d8\u662f\u8fde\u63a5\u5728____\u3002',
#   u'A\u3001\u6253\u5370\u673a\u63a5\u53e3\u4e0a\u7684',
#   u'B\u3001\u663e\u793a\u5668\u63a5\u53e3\u4e0a\u7684',
#   u'C\u3001\u5e76\u884c\u63a5\u53e3\u4e0a\u7684',
#   u'D\u3001\u4e32\u884c\u63a5\u53e3\u4e0a\u7684'],
#  [u'\u8ba1\u7b97\u673a\u7684\u901a\u7528\u6027\u4f7f\u5176\u53ef\u4ee5\u6c42\u89e3\u4e0d\u540c\u7684\u7b97\u672f\u548c\u903b\u8f91\u8fd0\u7b97\uff0c\u8fd9\u4e3b\u8981\u53d6\u51b3\u4e8e\u8ba1\u7b97\u673a\u7684______\u3002',
#   u'A\u3001\u6253\u5370\u673a\u63a5\u53e3\u4e0a\u7684',
#   u'B\u3001\u663e\u793a\u5668\u63a5\u53e3\u4e0a\u7684',
#   u'C\u3001\u5e76\u884c\u63a5\u53e3\u4e0a\u7684',
#   u'D\u3001\u4e32\u884c\u63a5\u53e3\u4e0a\u7684'],
#  [u'\u51e0\u5e74\u524d\u4e00\u4f4d\u82ac\u5170\u5927\u5b66\u751f\u4eba\u5728Internet \u4e0a\u516c\u5f00\u53d1\u5e03\u4e86\u4e00\u79cd\u514d\u8d39\u64cd\u4f5c\u7cfb\u7edf____\uff0c\u7ecf\u8fc7\u8bb8\u591a\u4eba\u7684\u52aa\u529b\uff0c\u8be5\u64cd\u4f5c\u7cfb\u7edf\u6b63\u4e0d\u65ad\u5b8c\u5584\uff0c\u5e76\u88ab\u63a8\u5e7f\u5e94\u7528\u3002 ',
#   u'A\u3001\u6253\u5370\u673a\u63a5\u53e3\u4e0a\u7684',
#   u'B\u3001\u663e\u793a\u5668\u63a5\u53e3\u4e0a\u7684',
#   u'C\u3001\u5e76\u884c\u63a5\u53e3\u4e0a\u7684',
#   u'D\u3001\u4e32\u884c\u63a5\u53e3\u4e0a\u7684'],
#  [u'\u51e0\u5e74\u524d\u4e00\u4f4d\u82ac\u5170\u5927\u5b66\u751f\u4eba\u5728Internet \u4e0a\u516c\u5f00\u53d1\u5e03\u4e86\u4e00\u79cd\u514d\u8d39\u64cd\u4f5c\u7cfb\u7edf____\uff0c\u7ecf\u8fc7\u8bb8\u591a\u4eba\u7684\u52aa\u529b\uff0c\u8be5\u64cd\u4f5c\u7cfb\u7edf\u6b63\u4e0d\u65ad\u5b8c\u5584\uff0c\u5e76\u88ab\u63a8\u5e7f\u5e94\u7528\u3002 ',
#   u'A\u3001\u53d1\u6563\u578b',
#   u'B\u3001\u96c6\u4e2d\u578b',
#   u'C\u3001\u5173\u7cfb\u578b',
#   u'D\u3001\u903b\u8f91\u578b'],
#  [u'\u7528\u9ad8\u7ea7\u7a0b\u5e8f\u8bbe\u8ba1\u8bed\u8a00\u7f16\u5199\u7684\u7a0b\u5e8f\uff0c\u8981\u8f6c\u6362\u6210\u7b49\u4ef7\u7684\u53ef\u6267\u884c\u7a0b\u5e8f\uff0c\u5fc5\u987b\u7ecf\u8fc7____\u3002 ',
#   u'A\u3001\u6c47\u7f16',
#   u'B\u3001\u7f16\u8f91',
#   u'C\u3001\u89e3\u91ca',
#   u'D\u3001\u7f16\u8bd1\u548c\u8fde\u63a5'],
#  [u'\u4e00\u822c\u7528\u9ad8\u7ea7\u8bed\u8a00\u7f16\u5199\u7684\u5e94\u7528\u7a0b\u5e8f\u79f0\u4e3a____\u3002',
#   u'A\u3001\u7f16\u8bd1\u7a0b\u5e8f',
#   u'B\u3001\u7f16\u8f91\u7a0b\u5e8f',
#   u'C\u3001\u8fde\u63a5\u7a0b\u5e8f',
#   u'D\u3001\u6e90\u7a0b\u5e8f'],
#  [u'\u82e5\u5fae\u673a\u7cfb\u7edf\u9700\u8981\u70ed\u542f\u52a8\uff0c\u5e94\u540c\u65f6\u6309\u4e0b\u7ec4\u5408\u952e____\u3002',
#   u'A\u3001Ctrl+Alt+Break',
#   u'B\u3001Ctrl+Esc+Del',
#   u'C\u3001\u8fde\u63a5\u7a0b\u5e8f',
#   u'D\u3001\u6e90\u7a0b\u5e8f'],
#  [u'\u82e5\u5fae\u673a\u7cfb\u7edf\u9700\u8981\u70ed\u542f\u52a8\uff0c\u5e94\u540c\u65f6\u6309\u4e0b\u7ec4\u5408\u952e____\u3002',
#   u'A\u3001Ctrl+Alt+Break',
#   u'B\u3001Ctrl+Esc+Del',
#   u'C\u3001Ctrl+Alt+Del',
#   u'\uff24\u3001Ctrl+Shift+Break'],
#  [u'\u542f\u52a8Windows\u7cfb\u7edf\u65f6\uff0c\u8981\u60f3\u76f4\u63a5\u8fdb\u5165\u6700\u5c0f\u7cfb\u7edf\u914d\u7f6e\u7684\u5b89\u5168\u6a21\u5f0f\uff0c\u6309____\u3002',
#   u'A\u3001F7\u952e',
#   u'B\u3001F8\u952e',
#   u'C\u3001F9\u952e',
#   u'D\u3001F10\u952e'],
#  [u'\u5728\u201c\u8bb0\u4e8b\u672c\u201d\u6216\u201c\u5199\u5b57\u677f\u201d\u7a97\u53e3\u4e2d\uff0c\u5bf9\u5f53\u524d\u7f16\u8f91\u7684\u6587\u6863\u8fdb\u884c\u5b58\u50a8\uff0c\u53ef\u4ee5\u7528____\u5feb\u6377\u952e\u3002',
#   u'A\u3001Alt+F',
#   u'B\u3001Alt+S',
#   u'C\u3001Ctrl+S',
#   u'D\u3001Ctrl+F'],
#  [u'\u5728\u201c\u8bb0\u4e8b\u672c\u201d\u6216\u201c\u5199\u5b57\u677f\u201d\u7a97\u53e3\u4e2d\uff0c\u5bf9\u5f53\u524d\u7f16\u8f91\u7684\u6587\u6863\u8fdb\u884c\u5b58\u50a8\uff0c\u53ef\u4ee5\u7528____\u5feb\u6377\u952e\u3002',
#   u'A\u3001\u6811\u5f62\u7ed3\u6784',
#   u'B\u3001\u7ebf\u5f62\u7ed3\u6784',
#   u'C\u3001\u5c42\u6b21\u7ed3\u6784',
#   u'D\u3001\u7f51\u72b6\u7ed3\u6784'],
#  [u'\u5728Windows\u4e2d\uff0c\u5982\u679c\u60f3\u540c\u65f6\u6539\u53d8\u7a97\u53e3\u7684\u9ad8\u5ea6\u6216\u5bbd\u5ea6\uff0c\u53ef\u4ee5\u901a\u8fc7\u62d6\u653e____\u6765\u5b9e\u73b0\u3002',
#   u'A\u3001\u6811\u5f62\u7ed3\u6784',
#   u'B\u3001\u7ebf\u5f62\u7ed3\u6784',
#   u'C\u3001\u5c42\u6b21\u7ed3\u6784',
#   u'D\u3001\u7f51\u72b6\u7ed3\u6784'],
#  [u'\u5bf9\u4e8eWindows\uff0c\u4e0b\u9762\u4ee5____\u4e3a\u6269\u5c55\u540d\u7684\u6587\u4ef6\u662f\u4e0d\u80fd\u8fd0\u884c\u7684\u3002',
#   u'A\u3001\u6811\u5f62\u7ed3\u6784',
#   u'B\u3001\u7ebf\u5f62\u7ed3\u6784',
#   u'C\u3001\u5c42\u6b21\u7ed3\u6784',
#   u'D\u3001\u7f51\u72b6\u7ed3\u6784'],
#  [u'\u5728 Windows \u4e2d\u6709\u4e24\u4e2a\u7ba1\u7406\u7cfb\u7edf\u8d44\u6e90\u7684\u7a0b\u5e8f\u7ec4\uff0c\u5b83\u4eec\u662f____\u3002 ',
#   u'A\u3001\u201c\u6211\u7684\u7535\u8111\u201d\u548c\u201c\u63a7\u5236\u9762\u677f\u201d',
#   u'B\u3001\u201c\u8d44\u6e90\u7ba1\u7406\u5668\u201d\u548c\u201c\u63a7\u5236\u9762\u677f\u201d',
#   u'C\u3001\u5c42\u6b21\u7ed3\u6784',
#   u'D\u3001\u7f51\u72b6\u7ed3\u6784'],
#  [u'\u5728 Windows \u4e2d\u6709\u4e24\u4e2a\u7ba1\u7406\u7cfb\u7edf\u8d44\u6e90\u7684\u7a0b\u5e8f\u7ec4\uff0c\u5b83\u4eec\u662f____\u3002 ',
#   u'A\u3001\u201c\u6211\u7684\u7535\u8111\u201d\u548c\u201c\u63a7\u5236\u9762\u677f\u201d',
#   u'B\u3001\u201c\u8d44\u6e90\u7ba1\u7406\u5668\u201d\u548c\u201c\u63a7\u5236\u9762\u677f\u201d',
#   u'C\u3001\u201c\u6211\u7684\u7535\u8111\u201d\u548c\u201c\u8d44\u6e90\u7ba1\u7406\u5668\u201d',
#   u'D\u3001\u201c\u63a7\u5236\u9762\u677f\u201d\u548c\u201c\u5f00\u59cb\u201d\u83dc\u5355'],
#  [u'\u5728Windows\u4e2d\uff0c\u4e3a\u4e86\u67e5\u627e\u6587\u4ef6\u540d\u4ee5"A"\u5b57\u6bcd\u6253\u5934\u7684\u6240\u6709\u6587\u4ef6\uff0c\u5e94\u5f53\u5728\u67e5\u627e\u540d\u79f0\u6846\u5185\u8f93\u5165____\u3002',
#   u'A\u3001A',
#   u'B\u3001A*',
#   u'C\u3001A\uff1f',
#   u'D\u3001A#'],
#  [u'\u5728Windows\u4e2d\uff0c\u4e3a\u4e86\u67e5\u627e\u6587\u4ef6\u540d\u4ee5"A"\u5b57\u6bcd\u6253\u5934\uff0c\u540e\u8ddf\u4e00\u5b57\u6bcd\u7684\u6240\u6709\u6587\u4ef6\uff0c\u5e94\u5f53\u5728\u67e5\u627e\u540d\u79f0\u6846\u5185\u8f93\u5165____\u3002',
#   u'A\u3001A',
#   u'B\u3001A*',
#   u'C\u3001A\uff1f',
#   u'D\u3001A#'],
#  [u'\u63a7\u5236\u9762\u677f\u7684\u4e3b\u8981\u4f5c\u7528\u662f____\u3002',
#   u'A\u3001A',
#   u'B\u3001A*',
#   u'C\u3001A\uff1f',
#   u'D\u3001A#'],
#  [u'\u5408\u952e ____\u53ef\u4ee5\u6253\u5f00\u201c\u5f00\u59cb\u201d\u83dc\u5355\u3002 ',
#   u'A\u3001<Ctrl>',
#   u'+<O>',
#   u'B\u3001<Ctrl>',
#   u'+<Esc>'],
#  [u'\u5408\u952e ____\u53ef\u4ee5\u6253\u5f00\u201c\u5f00\u59cb\u201d\u83dc\u5355\u3002 ',
#   u'A\u3001<Ctrl>',
#   u'+<O>',
#   u'C\u3001<Ctrl>+<\u7a7a\u683c\u952e>',
#   u'D\u3001<Ctrl>+<Tab>'],
#  [u'\u5408\u952e ____\u53ef\u4ee5\u6253\u5f00\u201c\u5f00\u59cb\u201d\u83dc\u5355\u3002 ',
#   u'A\u3001Noname',
#   u'B\u3001Untitled',
#   u'C\u3001\u6587\u4ef61',
#   u'D\u3001\u6587\u68631'],
#  [u'\u5408\u952e ____\u53ef\u4ee5\u6253\u5f00\u201c\u5f00\u59cb\u201d\u83dc\u5355\u3002 ',
#   u'A\u3001\u7f16\u8f91',
#   u'B\u3001\u7a97\u53e3',
#   u'C\u3001\u89c6\u56fe',
#   u'D\u3001\u5de5\u5177'],
#  [u'\u4e0b\u5217\u5e26\u6709\u901a\u914d\u7b26\u7684\u6587\u4ef6\u540d\uff0c\u80fd\u8868\u793a\u6587\u4ef6ABC\u3001TXT\u7684\u662f____\u3002 ',
#   u'A\u3001*BC\u3001?',
#   u'B\u3001A?.*',
#   u'C\u3001?BC\u3001*',
#   u'D\u3001?.?'],
#  [u'\u4f7f\u7528\u201c\u5f00\u59cb\u201d\u83dc\u5355\u4e2d\u7684\u67e5\u627e\u547d\u4ee4\uff0c\u8981\u67e5\u627e\u7684\u6587\u4ef6\u540d\u4e2d\u53ef\u4ee5\u4f7f\u7528____\u3002',
#   u'A\u3001\u901a\u914d\u7b26?',
#   u'B\u3001\u901a\u914d\u7b26*',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u4f7f\u7528\u201c\u5f00\u59cb\u201d\u83dc\u5355\u4e2d\u7684\u67e5\u627e\u547d\u4ee4\uff0c\u8981\u67e5\u627e\u7684\u6587\u4ef6\u540d\u4e2d\u53ef\u4ee5\u4f7f\u7528____\u3002',
#   u'A\u3001\u901a\u914d\u7b26?',
#   u'B\u3001\u901a\u914d\u7b26*',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u4f7f\u7528\u201c\u5f00\u59cb\u201d\u83dc\u5355\u4e2d\u7684\u67e5\u627e\u547d\u4ee4\uff0c\u8981\u67e5\u627e\u7684\u6587\u4ef6\u540d\u4e2d\u53ef\u4ee5\u4f7f\u7528____\u3002',
#   u'A\u3001\u901a\u914d\u7b26?',
#   u'B\u3001\u901a\u914d\u7b26*',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u4f7f\u7528\u201c\u5f00\u59cb\u201d\u83dc\u5355\u4e2d\u7684\u67e5\u627e\u547d\u4ee4\uff0c\u8981\u67e5\u627e\u7684\u6587\u4ef6\u540d\u4e2d\u53ef\u4ee5\u4f7f\u7528____\u3002',
#   u'A\u3001\u901a\u914d\u7b26?',
#   u'B\u3001\u901a\u914d\u7b26*',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u4f7f\u7528\u201c\u5f00\u59cb\u201d\u83dc\u5355\u4e2d\u7684\u67e5\u627e\u547d\u4ee4\uff0c\u8981\u67e5\u627e\u7684\u6587\u4ef6\u540d\u4e2d\u53ef\u4ee5\u4f7f\u7528____\u3002',
#   u'A\u3001\u901a\u914d\u7b26?',
#   u'B\u3001\u901a\u914d\u7b26*',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u5bf9WINDOWS\u5e94\u7528\u7a0b\u5e8f\u7a97\u53e3\u5feb\u901f\u91cd\u65b0\u6392\u5217[\u5e73\u94fa\u6216\u5c42\u53e0]\u7684\u65b9\u6cd5\u662f: ____\u3002',
#   u'A\u3001\u53ef\u901a\u8fc7\u5de5\u5177\u680f\u6309\u94ae\u5b9e\u73b0',
#   u'B\u3001\u53ef\u901a\u8fc7\u4efb\u52a1\u680f\u5feb\u6377\u83dc\u5355\u5b9e\u73b0',
#   u'C\u3001\u4e24\u8005\u90fd\u53ef\u4ee5',
#   u'D\u3001\u4e24\u8005\u90fd\u4e0d\u53ef\u4ee5'],
#  [u'\u5bf9WINDOWS\u5e94\u7528\u7a0b\u5e8f\u7a97\u53e3\u5feb\u901f\u91cd\u65b0\u6392\u5217[\u5e73\u94fa\u6216\u5c42\u53e0]\u7684\u65b9\u6cd5\u662f: ____\u3002',
#   u'A\u3001\u53ef\u901a\u8fc7\u5de5\u5177\u680f\u6309\u94ae\u5b9e\u73b0',
#   u'B\u3001\u53ef\u901a\u8fc7\u4efb\u52a1\u680f\u5feb\u6377\u83dc\u5355\u5b9e\u73b0',
#   u'C\u3001\u53ef\u7528\u9f20\u6807\u8c03\u6574\u548c\u62d6\u52a8\u7a97\u53e3\u5b9e\u73b0',
#   u'D\u3001\u53ef\u901a\u8fc7[\u5f00\u59cb]\u83dc\u5355\u4e0b\u7684[\u8bbe\u7f6e]\u547d\u4ee4\u5b9e\u73b0'],
#  [u'\u901a\u5e38\u628a\u8ba1\u7b97\u673a\u7f51\u7edc\u5b9a\u4e49\u4e3a____\u3002    ',
#   u'A\u3001\u53ef\u901a\u8fc7\u5de5\u5177\u680f\u6309\u94ae\u5b9e\u73b0',
#   u'B\u3001\u53ef\u901a\u8fc7\u4efb\u52a1\u680f\u5feb\u6377\u83dc\u5355\u5b9e\u73b0',
#   u'C\u3001\u53ef\u7528\u9f20\u6807\u8c03\u6574\u548c\u62d6\u52a8\u7a97\u53e3\u5b9e\u73b0',
#   u'D\u3001\u53ef\u901a\u8fc7[\u5f00\u59cb]\u83dc\u5355\u4e0b\u7684[\u8bbe\u7f6e]\u547d\u4ee4\u5b9e\u73b0'],
#  [u'\u901a\u5e38\u628a\u8ba1\u7b97\u673a\u7f51\u7edc\u5b9a\u4e49\u4e3a____\u3002    ',
#   u'A\u3001\u53ef\u901a\u8fc7\u5de5\u5177\u680f\u6309\u94ae\u5b9e\u73b0',
#   u'B\u3001\u53ef\u901a\u8fc7\u4efb\u52a1\u680f\u5feb\u6377\u83dc\u5355\u5b9e\u73b0',
#   u'C\u3001\u53ef\u7528\u9f20\u6807\u8c03\u6574\u548c\u62d6\u52a8\u7a97\u53e3\u5b9e\u73b0',
#   u'D\u3001\u53ef\u901a\u8fc7[\u5f00\u59cb]\u83dc\u5355\u4e0b\u7684[\u8bbe\u7f6e]\u547d\u4ee4\u5b9e\u73b0'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u6280\u672f\u5305\u542b\u7684\u4e24\u4e2a\u4e3b\u8981\u6280\u672f\u662f\u8ba1\u7b97\u673a\u6280\u672f\u548c____\u3002 ',
#   u'A\u3001\u5fae\u7535\u5b50\u6280\u672f',
#   u'B\u3001\u901a\u4fe1\u6280\u672f',
#   u'C\u3001\u53ef\u7528\u9f20\u6807\u8c03\u6574\u548c\u62d6\u52a8\u7a97\u53e3\u5b9e\u73b0',
#   u'D\u3001\u53ef\u901a\u8fc7[\u5f00\u59cb]\u83dc\u5355\u4e0b\u7684[\u8bbe\u7f6e]\u547d\u4ee4\u5b9e\u73b0'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u6280\u672f\u5305\u542b\u7684\u4e24\u4e2a\u4e3b\u8981\u6280\u672f\u662f\u8ba1\u7b97\u673a\u6280\u672f\u548c____\u3002 ',
#   u'A\u3001\u5fae\u7535\u5b50\u6280\u672f',
#   u'B\u3001\u901a\u4fe1\u6280\u672f',
#   u'C\u3001\u6570\u636e\u5904\u7406\u6280\u672f',
#   u'D\u3001\u81ea\u52a8\u5316\u6280\u672f'],
#  [u'\u8ba1\u7b97\u673a\u6280\u672f\u548c____\u6280\u672f\u76f8\u7ed3\u5408\uff0c\u51fa\u73b0\u4e86\u8ba1\u7b97\u673a\u7f51\u7edc\u3002',
#   u'A\u3001\u81ea\u52a8\u5316',
#   u'B\u3001\u901a\u4fe1',
#   u'C\u3001\u4fe1\u606f',
#   u'D\u3001\u7535\u7f06'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u662f\u4e00\u4e2a____\u7cfb\u7edf\u3002',
#   u'A\u3001\u7ba1\u7406\u4fe1\u606f\u7cfb\u7edf',
#   u'B\u3001\u7ba1\u7406\u6570\u636e\u7cfb\u7edf',
#   u'C\u3001\u4fe1\u606f',
#   u'D\u3001\u7535\u7f06'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u662f\u4e00\u4e2a____\u7cfb\u7edf\u3002',
#   u'A\u3001\u7ba1\u7406\u4fe1\u606f\u7cfb\u7edf',
#   u'B\u3001\u7ba1\u7406\u6570\u636e\u7cfb\u7edf',
#   u'C\u3001\u7f16\u8bd1\u7cfb\u7edf',
#   u'D\u3001\u5728\u534f\u8bae\u63a7\u5236\u4e0b\u7684\u591a\u673a\u4e92\u8054\u7cfb\u7edf'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u4e2d\uff0c\u53ef\u4ee5\u5171\u4eab\u7684\u8d44\u6e90\u662f____\u3002 ',
#   u'A\u3001\u786c\u4ef6\u548c\u8f6f\u4ef6',
#   u'B\u3001\u8f6f\u4ef6\u548c\u6570\u636e',
#   u'C\u3001\u7f16\u8bd1\u7cfb\u7edf',
#   u'D\u3001\u5728\u534f\u8bae\u63a7\u5236\u4e0b\u7684\u591a\u673a\u4e92\u8054\u7cfb\u7edf'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u4e2d\uff0c\u53ef\u4ee5\u5171\u4eab\u7684\u8d44\u6e90\u662f____\u3002 ',
#   u'A\u3001\u786c\u4ef6\u548c\u8f6f\u4ef6',
#   u'B\u3001\u8f6f\u4ef6\u548c\u6570\u636e',
#   u'C\u3001\u5916\u8bbe\u548c\u6570\u636e',
#   u'D\u3001\u786c\u4ef6\u3001\u8f6f\u4ef6\u548c\u6570\u636e'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u7684\u76ee\u6807\u662f\u5b9e\u73b0____\u3002',
#   u'A\u3001\u6570\u636e\u5904\u7406',
#   u'B\u3001\u6587\u732e\u68c0\u7d22',
#   u'C\u3001\u5916\u8bbe\u548c\u6570\u636e',
#   u'D\u3001\u786c\u4ef6\u3001\u8f6f\u4ef6\u548c\u6570\u636e'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u7684\u76ee\u6807\u662f\u5b9e\u73b0____\u3002',
#   u'A\u3001\u6570\u636e\u5904\u7406',
#   u'B\u3001\u6587\u732e\u68c0\u7d22',
#   u'C\u3001\u8d44\u6e90\u5171\u4eab\u548c\u4fe1\u606f\u4f20\u8f93',
#   u'D\u3001\u4fe1\u606f\u4f20\u8f93'],
#  [u'\u5173\u4e8eInternet\u7684\u6982\u5ff5\u53d9\u8ff0\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001\u6570\u636e\u5904\u7406',
#   u'B\u3001\u6587\u732e\u68c0\u7d22',
#   u'C\u3001\u8d44\u6e90\u5171\u4eab\u548c\u4fe1\u606f\u4f20\u8f93',
#   u'D\u3001\u4fe1\u606f\u4f20\u8f93'],
#  [u'\u5173\u4e8eInternet\u7684\u6982\u5ff5\u53d9\u8ff0\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001\u6570\u636e\u5904\u7406',
#   u'B\u3001\u6587\u732e\u68c0\u7d22',
#   u'C\u3001\u8d44\u6e90\u5171\u4eab\u548c\u4fe1\u606f\u4f20\u8f93',
#   u'D\u3001\u4fe1\u606f\u4f20\u8f93'],
#  [u'\u4e0b\u52174\u9879\u5185\u5bb9\u4e2d\uff0c\u4e0d\u5c5e\u4e8eInternet\uff08\u56e0\u7279\u7f51\uff09\u63d0\u4f9b\u7684\u670d\u52a1\u7684\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u90ae\u4ef6',
#   u'B\u3001\u6587\u4ef6\u4f20\u8f93',
#   u'C\u3001\u8fdc\u7a0b\u767b\u5f55',
#   u'D\u3001\u5b9e\u65f6\u76d1\u6d4b\u63a7\u5236'],
#  [u'\u4e07\u7ef4\u7f51WWW\u4ee5____\u65b9\u5f0f\u63d0\u4f9b\u4e16\u754c\u8303\u56f4\u7684\u591a\u5a92\u4f53\u4fe1\u606f\u670d\u52a1\u3002',
#   u'A\u3001\u6587\u672c',
#   u'B\u3001\u4fe1\u606f',
#   u'C\u3001\u8d85\u6587\u672c',
#   u'D\u3001\u58f0\u97f3'],
#  [u'\u8ba1\u7b97\u673a\u7528\u6237\u6709\u4e86\u53ef\u4ee5\u4e0a\u7f51\u7684\u8ba1\u7b97\u673a\u7cfb\u7edf\u540e\uff0c\u4e00\u822c\u9700\u627e\u4e00\u5bb6____\u6ce8\u7f51\u5165\u7f51\u3002',
#   u'A\u3001\u8f6f\u4ef6\u516c\u53f8',
#   u'B\u3001\u7cfb\u7edf\u96c6\u6210\u5546',
#   u'C\u3001ISP',
#   u'D\u3001\u7535\u4fe1\u5c40'],
#  [u'\u56e0\u7279\u7f51\u4e0a\u6bcf\u53f0\u8ba1\u7b97\u673a\u6709\u4e00\u4e2a\u89c4\u5b9a\u7684\u201c\u5730\u5740\u201d\uff0c\u8fd9\u4e2a\u5730\u5740\u88ab\u79f0\u4e3a____\u5730\u5740\u3002',
#   u'A\u3001TCP',
#   u'B\u3001IP',
#   u'C\u3001Web',
#   u'D\u3001HTML'],
#  [u'\u6bcf\u53f0\u8ba1\u7b97\u673a\u5fc5\u987b\u77e5\u9053\u5bf9\u65b9\u7684____ \u624d\u80fd\u5728Internet\u4e0a\u4e0e\u4e4b\u901a\u4fe1\u3002',
#   u'A\u3001\u7535\u8bdd\u53f7\u7801',
#   u'B\u3001\u4e3b\u673a\u53f7',
#   u'C\u3001IP\u5730\u5740',
#   u'D\u3001\u90ae\u7f16\u4e0e\u901a\u4fe1\u5730\u5740'],
#  [u'\u5f53\u524d\u4f7f\u7528\u7684IP\u5730\u5740\u662f\u4e00\u4e2a____ \u7684\u4e8c\u8fdb\u5236\u5730\u5740\u3002',
#   u'A\u3001\u7535\u8bdd\u53f7\u7801',
#   u'B\u3001\u4e3b\u673a\u53f7',
#   u'C\u3001IP\u5730\u5740',
#   u'D\u3001\u90ae\u7f16\u4e0e\u901a\u4fe1\u5730\u5740'],
#  [u'\u4e0b\u5217\u5173\u4e8eIP\u7684\u8bf4\u6cd5\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001IP\u5730\u5740\u5728Internet\u4e0a\u662f\u552f\u4e00\u7684',
#   u'B\u3001IP\u5730\u5740\u753132\u4f4d\u5341\u8fdb\u5236\u6570\u7ec4\u6210',
#   u'C\u3001IP\u5730\u5740',
#   u'D\u3001\u90ae\u7f16\u4e0e\u901a\u4fe1\u5730\u5740'],
#  [u'\u4e0b\u5217\u5173\u4e8eIP\u7684\u8bf4\u6cd5\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001IP\u5730\u5740\u5728Internet\u4e0a\u662f\u552f\u4e00\u7684',
#   u'B\u3001IP\u5730\u5740\u753132\u4f4d\u5341\u8fdb\u5236\u6570\u7ec4\u6210',
#   u'C\u3001IP\u5730\u5740\u662fInternet\u4e0a\u4e3b\u673a\u7684\u6570\u5b57\u6807\u8bc6',
#   u'D\u3001IP\u5730\u5740\u6307\u51fa\u4e86\u8be5\u8ba1\u7b97\u673a\u8fde\u63a5\u5230\u54ea\u4e2a\u7f51\u7edc\u4e0a'],
#  [u'\u4e0b\u5217\u5173\u4e8eIP\u7684\u8bf4\u6cd5\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001DNS',
#   u'B\u3001URL',
#   u'C\u3001UNIX',
#   u'D\u3001ISDN'],
#  [u'\u4e0b\u5217\u5173\u4e8eIP\u7684\u8bf4\u6cd5\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001128',
#   u'B\u300164',
#   u'C\u3001UNIX',
#   u'D\u3001ISDN'],
#  [u'\u4e0b\u5217\u5173\u4e8eIP\u7684\u8bf4\u6cd5\u9519\u8bef\u7684\u662f____\u3002',
#   u'A\u3001128',
#   u'B\u300164',
#   u'C\u30011024',
#   u'D\u3001256'],
#  [u'\u4ee5____\u5c06\u7f51\u7edc\u5212\u5206\u4e3a\u5e7f\u57df\u7f51\u3001\u57ce\u57df\u7f51\u548c\u5c40\u57df\u7f51\u3002',
#   u'A\u3001128',
#   u'B\u300164',
#   u'C\u30011024',
#   u'D\u3001256'],
#  [u'\u4e0b\u5217\u54ea\u4e9b\u8ba1\u7b97\u673a\u7f51\u7edc\u4e0d\u662f\u6309\u8986\u76d6\u5730\u57df\u5212\u5206\u7684____\u3002',
#   u'A\u3001\u5c40\u57df\u7f51',
#   u'B\u3001\u90fd\u5e02\u7f51',
#   u'C\u3001\u5e7f\u57df\u7f51',
#   u'D\u3001\u661f\u578b\u7f51'],
#  [u'\u4e0b\u5217\u54ea\u4e9b\u8ba1\u7b97\u673a\u7f51\u7edc\u4e0d\u662f\u6309\u8986\u76d6\u5730\u57df\u5212\u5206\u7684____\u3002',
#   u'A\u3001\u7f8e\u56fd',
#   u'B\u3001\u82f1\u56fd',
#   u'C\u3001\u5fb7\u56fd',
#   u'D\u3001\u6fb3\u5927\u5229\u4e9a'],
#  [u'\u4e00\u822c\u60c5\u51b5\u4e0b\uff0c\u6821\u56ed\u7f51\u5c5e\u4e8e_____\u3002',
#   u'A\u3001LAN',
#   u'B\u3001WAN',
#   u'C\u3001MAN',
#   u'D\u3001GAN'],
#  [u'\u5728\u8ba1\u7b97\u673a\u7f51\u7edc\u4e2dWAN\u8868\u793a____\u3002',
#   u'A\u3001\u6709\u7ebf\u7f51',
#   u'B\u3001\u65e0\u7ebf\u7f51',
#   u'C\u3001\u5c40\u57df\u7f51',
#   u'D\u3001\u5e7f\u57df\u7f51'],
#  [u'\u4e0b\u5217\u5173\u4e8e\u5c40\u57df\u7f51\u7279\u70b9\u7684\u53d9\u8ff0\u4e2d\uff0c\u4e0d\u6b63\u786e\u7684\u662f____\u3002',
#   u'A\u3001\u5c40\u57df\u7f51\u7684\u8986\u76d6\u8303\u56f4\u6709\u9650',
#   u'B\u3001\u8bef\u7801\u7387\u9ad8',
#   u'C\u3001\u5c40\u57df\u7f51',
#   u'D\u3001\u5e7f\u57df\u7f51'],
#  [u'\u4e0b\u5217\u5173\u4e8e\u5c40\u57df\u7f51\u7279\u70b9\u7684\u53d9\u8ff0\u4e2d\uff0c\u4e0d\u6b63\u786e\u7684\u662f____\u3002',
#   u'A\u3001\u5c40\u57df\u7f51\u7684\u8986\u76d6\u8303\u56f4\u6709\u9650',
#   u'B\u3001\u8bef\u7801\u7387\u9ad8',
#   u'C\u3001\u6709\u8f83\u9ad8\u7684\u4f20\u8f93\u901f\u7387',
#   u'D\u3001\u76f8\u5bf9\u4e8e\u5e7f\u57df\u7f51\u6613\u4e8e\u5efa\u7acb\u3001\u7ba1\u7406\u3001\u7ef4\u62a4\u548c\u6269\u5c55'],
#  [u'\u5728\u8ba1\u7b97\u673a\u7f51\u7edc\u7cfb\u7edf\u4e2d\uff0cWAN\u6307\u7684\u662f____\u3002',
#   u'A\u3001\u57ce\u57df\u7f51',
#   u'B\u3001\u5c40\u57df\u7f51',
#   u'C\u3001\u5e7f\u57df\u7f51',
#   u'D\u3001\u4ee5\u592a\u7f51'],
#  [u'\u4e0b\u5217\u7535\u5b50\u90ae\u4ef6\u5730\u5740\u4e2d\u6b63\u786e\u7684\u662f____\u3002 ',
#   u'A\u3001zhangsan&sina\u3001com',
#   u'B\u3001lisi!126\u3001com',
#   u'C\u3001\u5e7f\u57df\u7f51',
#   u'D\u3001\u4ee5\u592a\u7f51'],
#  [u'\u4e0b\u5217\u7535\u5b50\u90ae\u4ef6\u5730\u5740\u4e2d\u6b63\u786e\u7684\u662f____\u3002 ',
#   u'A\u3001zhangsan&sina\u3001com',
#   u'B\u3001lisi!126\u3001com',
#   u'C\u3001zhang$san@qq\u3001com',
#   u'D\u3001lisi_1982@sohu\u3001com'],
#  [u'\u7535\u5b50\u90ae\u4ef6\u5230\u8fbe\u65f6\uff0c\u5982\u679c\u5e76\u6ca1\u6709\u5f00\u673a\uff0c\u90a3\u4e48\u90ae\u4ef6\u5c06_____\u3002',
#   u'A\u3001',
#   u'\u9000\u56de\u7ed9\u53d1\u4ef6\u4eba',
#   u'B\u3001',
#   u'\u5f00\u673a\u65f6\u5bf9\u65b9\u91cd\u65b0\u53d1\u9001'],
#  [u'\u7535\u5b50\u90ae\u4ef6\u5230\u8fbe\u65f6\uff0c\u5982\u679c\u5e76\u6ca1\u6709\u5f00\u673a\uff0c\u90a3\u4e48\u90ae\u4ef6\u5c06_____\u3002',
#   u'C\u3001',
#   u'\u8be5\u90ae\u4ef6\u4e22\u5931',
#   u'D\u3001',
#   u'\u4fdd\u5b58\u5728\u670d\u52a1\u5546\u7684E-mail\u670d\u52a1\u5668\u4e0a'],
#  [u'\u8981\u5728Web\u6d4f\u89c8\u5668\u4e2d\u67e5\u770b\u67d0\u4e00\u516c\u53f8\u7684\u4e3b\u9875\uff0c\u5fc5\u987b\u77e5\u9053____\u3002',
#   u'A\u3001\u8be5\u516c\u53f8\u7684\u7535\u5b50\u90ae\u4ef6\u5730\u5740',
#   u'B\u3001\u8be5\u516c\u53f8\u6240\u5728\u7684\u7701\u5e02',
#   u'D\u3001',
#   u'\u4fdd\u5b58\u5728\u670d\u52a1\u5546\u7684E-mail\u670d\u52a1\u5668\u4e0a'],
#  [u'\u8981\u5728Web\u6d4f\u89c8\u5668\u4e2d\u67e5\u770b\u67d0\u4e00\u516c\u53f8\u7684\u4e3b\u9875\uff0c\u5fc5\u987b\u77e5\u9053____\u3002',
#   u'A\u3001\u8be5\u516c\u53f8\u7684\u7535\u5b50\u90ae\u4ef6\u5730\u5740',
#   u'B\u3001\u8be5\u516c\u53f8\u6240\u5728\u7684\u7701\u5e02',
#   u'C\u3001\u8be5\u516c\u53f8\u7684\u90ae\u653f\u7f16\u7801',
#   u'D\u3001\u8be5\u516c\u53f8\u7684WWW\u5730\u5740'],
#  [u'\u8981\u5728Web\u6d4f\u89c8\u5668\u4e2d\u67e5\u770b\u67d0\u4e00\u516c\u53f8\u7684\u4e3b\u9875\uff0c\u5fc5\u987b\u77e5\u9053____\u3002',
#   u'A\u3001Internet',
#   u'Explorer',
#   u'B\u3001Outlook',
#   u'Express'],
#  [u'\u8981\u5728Web\u6d4f\u89c8\u5668\u4e2d\u67e5\u770b\u67d0\u4e00\u516c\u53f8\u7684\u4e3b\u9875\uff0c\u5fc5\u987b\u77e5\u9053____\u3002',
#   u'A\u3001Internet',
#   u'Explorer',
#   u'C\u3001Yahoo',
#   u'D\u3001FrontPage'],
#  [u'\u4e92\u8054\u7f51\u4e0a\u7684\u670d\u52a1\u90fd\u57fa\u4e8e\u4e00\u79cd\u534f\u8bae\uff0cwww\u670d\u52a1\u57fa\u4e8e____\u534f\u8bae\u3002',
#   u'A\u3001POP3',
#   u'B\u3001SMTP',
#   u'C\u3001HTTP',
#   u'D\u3001TELNET'],
#  [u'\u5728Internet\u7684\u57df\u540d\u4e2d\uff0c\u4ee3\u8868\u8ba1\u7b97\u673a\u6240\u5728\u56fd\u5bb6\u6216\u5730\u533a\u7684\u7b26\u53f7\u201c.cn\u201d\u662f\u6307____\u3002',
#   u'A\u3001\u4e2d\u56fd',
#   u'B\u3001\u53f0\u6e7e',
#   u'C\u3001\u9999\u6e2f',
#   u'D\u3001\u52a0\u62ff\u5927'],
#  [u'\u7f51\u5740\u5b57\u7b26\u7684\u5f00\u5934\u7684\u201chttp\u201d\u8868\u793a____\u3002 ',
#   u'A\u3001\u9ad8\u7ea7\u7a0b\u5e8f\u8bbe\u8ba1\u8bed\u8a00',
#   u'B\u3001\u57df\u540d',
#   u'C\u3001\u8d85\u6587\u672c\u4f20\u8f93\u534f\u8bae',
#   u'D\u3001\u7f51\u5740'],
#  [u'\u57df\u540d\u4e2d\u7684\u540e\u7f00.gov\u8868\u793a\u673a\u6784\u6240\u5c5e\u7c7b\u578b\u4e3a____\u3002',
#   u'A\u3001\u519b\u4e8b\u673a\u6784',
#   u'B\u3001\u653f\u5e9c\u673a\u6784',
#   u'C\u3001\u6559\u80b2\u673a\u6784',
#   u'D\u3001\u5546\u4e1a\u516c\u53f8'],
#  [u'\u57df\u540d\u4e2d\u7684\u540e\u7f00.com\u8868\u793a\u673a\u6784\u6240\u5c5e\u7c7b\u578b\u4e3a____\u3002',
#   u'A\u3001\u519b\u4e8b\u673a\u6784',
#   u'B\u3001\u653f\u5e9c\u673a\u6784',
#   u'C\u3001\u6559\u80b2\u673a\u6784',
#   u'D\u3001\u5546\u4e1a\u516c\u53f8'],
#  [u'\u57df\u540d\u4e2d\u7684\u540e\u7f00.edu\u8868\u793a\u673a\u6784\u6240\u5c5e\u7c7b\u578b\u4e3a____\u3002',
#   u'A\u3001\u519b\u4e8b\u673a\u6784',
#   u'B\u3001\u653f\u5e9c\u673a\u6784',
#   u'C\u3001\u6559\u80b2\u673a\u6784',
#   u'D\u3001\u5546\u4e1a\u516c\u53f8'],
#  [u'\u57df\u540d\u4e2d\u7684\u540e\u7f00.edu\u8868\u793a\u673a\u6784\u6240\u5c5e\u7c7b\u578b\u4e3a____\u3002',
#   u'A\u3001\u901a\u4fe1\u673a\u6784',
#   u'B\u3001\u7f51\u7edc\u673a\u6784',
#   u'C\u3001\u7ec4\u7ec7\u673a\u6784',
#   u'D\u3001\u5546\u4e1a\u673a\u6784'],
#  [u'\u6211\u56fd\u653f\u5e9c\u90e8\u95e8\u8981\u5efa\u7acbWWW\u7f51\u7ad9\uff0c\u5176\u57df\u540d\u7684\u540e\u7f00\u5e94\u8be5\u662f____\u3002',
#   u'A\u3001com.au',
#   u'B\u3001gov.au',
#   u'C\u3001gov.cn',
#   u'D\u3001net.cn'],
#  [u'\u6211\u56fd\u653f\u5e9c\u90e8\u95e8\u8981\u5efa\u7acbWWW\u7f51\u7ad9\uff0c\u5176\u57df\u540d\u7684\u540e\u7f00\u5e94\u8be5\u662f____\u3002',
#   u'A\u3001\u670b\u514b',
#   u'B\u3001\u6d77\u5ba2',
#   u'C\u3001\u7f51\u866b',
#   u'D\u3001\u9ed1\u5ba2'],
#  [u'\u4e2d\u56fd\u4e92\u8054\u7f51\u7edc\u4fe1\u606f\u4e2d\u5fc3\u7684\u82f1\u6587\u7f29\u5199\u662f____\u3002',
#   u'A\u3001CNNIC',
#   u'B\u3001Chinanic',
#   u'C\u3001Cernic',
#   u'D\u3001Internic'],
#  [u'\u4e2d\u56fd\u4e92\u8054\u7f51\u7edc\u4fe1\u606f\u4e2d\u5fc3\u7684\u82f1\u6587\u7f29\u5199\u662f____\u3002',
#   u'A\u3001\u6587\u4ef6\u4f20\u8f93',
#   u'B\u3001\u7f51\u7ad9\u4f20\u8f93',
#   u'C\u3001\u6587\u4ef6\u538b\u7f29',
#   u'D\u3001\u6587\u4ef6\u89e3\u538b'],
#  [u'\u4e2d\u56fd\u4e92\u8054\u7f51\u7edc\u4fe1\u606f\u4e2d\u5fc3\u7684\u82f1\u6587\u7f29\u5199\u662f____\u3002',
#   u'A\u3001\u7528\u6237\u540d',
#   u'B\u3001\u67d0\u7f51\u7ad9\u540d',
#   u'C\u3001\u67d0\u7f51\u7edc\u516c\u53f8\u540d',
#   u'D\u3001\u4e3b\u673a\u57df\u540d'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u53ef\u4ee5\u6709\u591a\u79cd\u5206\u7c7b\uff0c\u6309\u62d3\u6251\u7ed3\u6784\u5206\uff0c\u53ef\u4ee5\u5206\u4e3a____\u7ed3\u6784\u7b49\u3002',
#   u'A\u3001\u5c40\u57df\u7f51\u3001\u57ce\u57df\u7f51\u3001\u5e7f\u57df\u7f51',
#   u'B\u3001\u7269\u7406\u7f51\u3001\u903b\u8f91\u7f51\ue004',
#   u'C\u3001\u67d0\u7f51\u7edc\u516c\u53f8\u540d',
#   u'D\u3001\u4e3b\u673a\u57df\u540d'],
#  [u'\u8ba1\u7b97\u673a\u7f51\u7edc\u53ef\u4ee5\u6709\u591a\u79cd\u5206\u7c7b\uff0c\u6309\u62d3\u6251\u7ed3\u6784\u5206\uff0c\u53ef\u4ee5\u5206\u4e3a____\u7ed3\u6784\u7b49\u3002',
#   u'A\u3001\u5c40\u57df\u7f51\u3001\u57ce\u57df\u7f51\u3001\u5e7f\u57df\u7f51',
#   u'B\u3001\u7269\u7406\u7f51\u3001\u903b\u8f91\u7f51\ue004',
#   u'C\u3001\u603b\u7ebf\u7f51\u3001\u73af\u5f62\u7f51\u3001\u661f\u5f62\u7f51',
#   u'D\u3001ATM\u7f51'],
#  [u'\u5728\u5b9e\u9645\u5e94\u7528\u7684\u7f51\u7edc\u4e2d\uff0c\u7f51\u7edc\u7cfb\u7edf\u8d44\u6e90\u53ca\u5b89\u5168\u6027\u7ba1\u7406\u76f8\u5bf9\u96c6\u4e2d\u5728\u4e00\u79cd\u591a\u7528\u6237\u8ba1\u7b97\u673a\u4e0a\uff0c\u8fd9\u79cd\u673a\u5668\u79f0\u4e3a____\u3002',
#   u'A\u3001\u5de5\u4f5c\u7ad9',
#   u'B\u3001\u7ec8\u7aef\u673a',
#   u'C\u3001\u4e2a\u4eba\u673a',
#   u'D\u3001\u670d\u52a1\u5668'],
#  [u'\u4e3a\u7f51\u7edc\u63d0\u4f9b\u5171\u4eab\u8d44\u6e90\u5e76\u5bf9\u8fd9\u4e9b\u8d44\u6e90\u8fdb\u884c\u7ba1\u7406\u7684\u8ba1\u7b97\u673a\u79f0\u4e4b\u4e3a____\u3002',
#   u'A\u3001\u7f51\u5361',
#   u'B\u3001\u670d\u52a1\u5668',
#   u'C\u3001\u5de5\u4f5c\u7ad9',
#   u'D\u3001\u7f51\u6865'],
#  [u'\u5f53\u524d\u4e16\u754c\u4e0a\u4f7f\u7528\u6700\u591a\uff0c\u8986\u76d6\u9762\u6700\u5927\u7684\u7f51\u7edc\uff0c\u53eb\u4f5c____\u3002',
#   u'A\u3001Intranet',
#   u'B\u3001Internet',
#   u'C\u3001ARPANET',
#   u'D\u3001MILNET'],
#  [u'\u4f7f\u7528\u56fd\u9645\u6237\u8054\u7f51\u65f6\uff0c\u901a\u5e38\u4f7f\u7528\u7684\u7f51\u7edc\u901a\u4fe1\u534f\u8bae\u662f____\u3002',
#   u'A\u3001NCP',
#   u'B\u3001NETBUEI',
#   u'C\u3001OSI',
#   u'D\u3001TCP/IP'],
#  [u'\u7535\u5b50\u90ae\u4ef6E-mail\u662f\u901a\u8fc7____\u4f20\u9012\u7528\u6237\u7535\u5b50\u6587\u4ef6\u7684\u3002',
#   u'A\u3001\u4e2a\u4eba\u8ba1\u7b97\u673a',
#   u'B\u3001\u7f51\u7edc\u64cd\u4f5c\u7cfb\u7edf',
#   u'C\u3001\u5de5\u4f5c\u7ad9',
#   u'D\u3001\u90ae\u4ef6\u6536\u53d1\u670d\u52a1\u5668'],
#  [u'\u4ee5\u4e0b\u7684\u641c\u7d22\u5f15\u64ce\u4e2d\uff0c\u5f53\u524d\u4f7f\u7528\u6700\u5e7f\u6cdb\u7684\u4e2d\u6587\u641c\u7d22\u5f15\u64ce\u662f____\u3002',
#   u'A\u3001http://www\u3001yahoo\u3001com\ue004',
#   u'B\u3001http://www\u3001baidu\u3001com',
#   u'C\u3001\u5de5\u4f5c\u7ad9',
#   u'D\u3001\u90ae\u4ef6\u6536\u53d1\u670d\u52a1\u5668'],
#  [u'\u4ee5\u4e0b\u7684\u641c\u7d22\u5f15\u64ce\u4e2d\uff0c\u5f53\u524d\u4f7f\u7528\u6700\u5e7f\u6cdb\u7684\u4e2d\u6587\u641c\u7d22\u5f15\u64ce\u662f____\u3002',
#   u'A\u3001http://www\u3001yahoo\u3001com\ue004',
#   u'B\u3001http://www\u3001baidu\u3001com',
#   u'C\u3001http://www\u3001google\u3001com\ue004',
#   u'D\u3001'],
#  [u'\u4ee5\u4e0b\u7684\u641c\u7d22\u5f15\u64ce\u4e2d\uff0c\u5f53\u524d\u4f7f\u7528\u6700\u5e7f\u6cdb\u7684\u4e2d\u6587\u641c\u7d22\u5f15\u64ce\u662f____\u3002',
#   u'A\u3001MIS',
#   u'B\u3001\u552f\u4e00\u7684\u4e0a\u7f51\u5de5\u5177',
#   u'C\u3001http://www\u3001google\u3001com\ue004',
#   u'D\u3001'],
#  [u'\u4ee5\u4e0b\u7684\u641c\u7d22\u5f15\u64ce\u4e2d\uff0c\u5f53\u524d\u4f7f\u7528\u6700\u5e7f\u6cdb\u7684\u4e2d\u6587\u641c\u7d22\u5f15\u64ce\u662f____\u3002',
#   u'A\u3001MIS',
#   u'B\u3001\u552f\u4e00\u7684\u4e0a\u7f51\u5de5\u5177',
#   u'C\u3001\u4e00\u79cdWeb\u9875\u7684\u6d4f\u89c8\u5668',
#   u'D\u3001\u6536\u53d1\u7535\u5b50\u90ae\u4ef6\u7684\u5de5\u5177'],
# ...
#   u'C\u3001\u7a83\u53d6\u8ba1\u7b97\u673a\u7f51\u7edc\u7cfb\u7edf\u4e2d\u7684\u7528\u6237\u5bc6\u7801',
#   u'D\u3001\u53d1\u5e03\u75c5\u6bd2'],
#  [u'\u56e0\u7279\u7f51\u63d0\u4f9b\u7684\u6587\u4ef6\u4f20\u8f93\u529f\u80fd\u662f____\u3002',
#   u'A\u3001FTP',
#   u'B\u3001HTTP',
#   u'C\u3001E-MAIL',
#   u'D\u3001BBS'],
#  [u'\u753b\u56fe\u4e2d\uff0c\u9009\u62e9\u7f16\u8f91\u2192\u590d\u5236\u83dc\u5355\u547d\u4ee4\uff0c\u9009\u5b9a\u7684\u5bf9\u8c61\u5c06\u88ab\u590d\u5236\u5230____\u4e2d\u3002',
#   u'A\u3001\u6211\u7684\u6587\u6863',
#   u'B\u3001\u684c\u9762',
#   u'C\u3001\u526a\u8d34\u677f',
#   u'D\u3001\u5176\u5b83\u7684\u56fe\u753b'],
#  [u'\u8ba1\u7b97\u673a\u5b58\u50a8\u5668\u7684\u4e00\u4e2a\u5b57\u8282\u53ef\u4ee5\u5b58\u653e____\u3002',
#   u'A\u3001\u4e00\u4e2a\u6c49\u5b57',
#   u'B\u3001\u4e8c\u4e2a\u6c49\u5b57',
#   u'C\u3001\u526a\u8d34\u677f',
#   u'D\u3001\u5176\u5b83\u7684\u56fe\u753b'],
#  [u'\u8ba1\u7b97\u673a\u5b58\u50a8\u5668\u7684\u4e00\u4e2a\u5b57\u8282\u53ef\u4ee5\u5b58\u653e____\u3002',
#   u'A\u3001\u4e00\u4e2a\u6c49\u5b57',
#   u'B\u3001\u4e8c\u4e2a\u6c49\u5b57',
#   u'C\u3001\u4e00\u4e2a\u897f\u6587\u5b57\u7b26',
#   u'D\u3001\u4e8c\u4e2a\u897f\u6587\u5b57\u7b26'],
#  [u'\u5212\u5206\u8ba1\u7b97\u673a\u53d1\u5c55\u56db\u4e2a\u65f6\u4ee3\u7684\u4e3b\u8981\u4f9d\u636e\u662f____\u3002',
#   u'A\u3001\u56e0\u7279\u7f51',
#   u'B\u3001\u4e07\u7ef4\u7f51',
#   u'C\u3001\u82f1\u7279\u5c14\u7f51',
#   u'D\u3001\u4ee5\u592a\u7f51'],
#  [u'\u5212\u5206\u8ba1\u7b97\u673a\u53d1\u5c55\u56db\u4e2a\u65f6\u4ee3\u7684\u4e3b\u8981\u4f9d\u636e\u662f____\u3002',
#   u'A\u3001\u56e0\u7279\u7f51',
#   u'B\u3001\u4e07\u7ef4\u7f51',
#   u'C\u3001\u82f1\u7279\u5c14\u7f51',
#   u'D\u3001\u4ee5\u592a\u7f51'],
#  [u'\u5212\u5206\u8ba1\u7b97\u673a\u53d1\u5c55\u56db\u4e2a\u65f6\u4ee3\u7684\u4e3b\u8981\u4f9d\u636e\u662f____\u3002',
#   u'A\u3001\u56e0\u7279\u7f51',
#   u'B\u3001\u4e07\u7ef4\u7f51',
#   u'C\u3001\u82f1\u7279\u5c14\u7f51',
#   u'D\u3001\u4ee5\u592a\u7f51'],
#  [u'\u5212\u5206\u8ba1\u7b97\u673a\u53d1\u5c55\u56db\u4e2a\u65f6\u4ee3\u7684\u4e3b\u8981\u4f9d\u636e\u662f____\u3002',
#   u'A\u3001\u56e0\u7279\u7f51',
#   u'B\u3001\u4e07\u7ef4\u7f51',
#   u'C\u3001UNIX\u7cfb\u7edf',
#   u'D\u3001\u6570\u636e\u5e93\u7cfb\u7edf'],
#  [u'\u5728\u7f51\u9875\u4e2d\uff0c\u8868\u5355\u7684\u4f5c\u7528\u4e3b\u8981\u662f____\u3002',
#   u'A\u3001\u6536\u96c6\u8d44\u6599',
#   u'B\u3001\u53d1\u5e03\u4fe1\u606f',
#   u'C\u3001\u5904\u7406\u4fe1\u606f',
#   u'D\u3001\u5206\u6790\u4fe1\u606f'],
#  [u'\u5728Windows\u4e2d\u540c\u65f6\u6253\u5f00\u591a\u4e2a\u7a97\u53e3\u540e\uff0c\u4e00\u4e9b\u7a97\u53e3\u4f1a\u906e\u4f4f\u53e6\u5916\u4e00\u4e9b\u7a97\u53e3\uff0c\u8fd9\u65f6\u7528\u6237\u53ef\u5c06\u9f20\u6807\u79fb\u5230____\u7a7a\u767d\u533a\u57df\u5355\u51fb\u9f20\u6807\u53f3\u952e\u542f\u52a8\u5feb\u6377\u83dc\u5355\u6765\u91cd\u65b0\u6392\u5217\u8fd9\u4e9b\u7a97\u53e3\u3002',
#   u'A\u3001\u6807\u9898\u680f',
#   u'B\u3001\u5de5\u5177\u680f',
#   u'C\u3001\u4efb\u52a1\u680f',
#   u'D\u3001\u83dc\u5355\u680f'],
#  [u'\u4e0b\u5217\u5c5e\u4e8e\u8ba1\u7b97\u673a\u7cfb\u7edf\u8f6f\u4ef6\u7684\u662f____\u3002',
#   u'A\u3001\u5b57\u5904\u7406\u8f6f\u4ef6',
#   u'B\u3001\u7535\u5b50\u8868\u683c\u8f6f\u4ef6',
#   u'C\u3001\u64cd\u4f5c\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001EXCEL'],
#  [u'\u4e3a\u4e86\u63d0\u9ad8\u4f7f\u7528\u6d4f\u89c8\u5668\u7684\u5b89\u5168\u6027\uff0c\u6211\u4eec\u53ef\u4ee5\u91c7\u53d6\u8bb8\u591a\u63aa\u65bd\uff0c\u4e0b\u5217\u63aa\u65bd\u65e0\u6548\u7684\u662f____\u3002',
#   u'A\u3001\u5b57\u5904\u7406\u8f6f\u4ef6',
#   u'B\u3001\u7535\u5b50\u8868\u683c\u8f6f\u4ef6',
#   u'C\u3001\u64cd\u4f5c\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001EXCEL'],
#  [u'\u4e3a\u4e86\u63d0\u9ad8\u4f7f\u7528\u6d4f\u89c8\u5668\u7684\u5b89\u5168\u6027\uff0c\u6211\u4eec\u53ef\u4ee5\u91c7\u53d6\u8bb8\u591a\u63aa\u65bd\uff0c\u4e0b\u5217\u63aa\u65bd\u65e0\u6548\u7684\u662f____\u3002',
#   u'A\u3001\u5b57\u5904\u7406\u8f6f\u4ef6',
#   u'B\u3001\u7535\u5b50\u8868\u683c\u8f6f\u4ef6',
#   u'C\u3001\u64cd\u4f5c\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001EXCEL'],
#  [u'\u4e3a\u4e86\u63d0\u9ad8\u4f7f\u7528\u6d4f\u89c8\u5668\u7684\u5b89\u5168\u6027\uff0c\u6211\u4eec\u53ef\u4ee5\u91c7\u53d6\u8bb8\u591a\u63aa\u65bd\uff0c\u4e0b\u5217\u63aa\u65bd\u65e0\u6548\u7684\u662f____\u3002',
#   u'A\u300164MB',
#   u'B\u300164GB',
#   u'C\u3001\u64cd\u4f5c\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001EXCEL'],
#  [u'\u4e3a\u4e86\u63d0\u9ad8\u4f7f\u7528\u6d4f\u89c8\u5668\u7684\u5b89\u5168\u6027\uff0c\u6211\u4eec\u53ef\u4ee5\u91c7\u53d6\u8bb8\u591a\u63aa\u65bd\uff0c\u4e0b\u5217\u63aa\u65bd\u65e0\u6548\u7684\u662f____\u3002',
#   u'A\u300164MB',
#   u'B\u300164GB',
#   u'C\u300165.536MB',
#   u'D\u300165.536GB'],
#  [u'\u4e0b\u5217\u88ab\u8ba1\u7b97\u673a\u76f4\u63a5\u8bc6\u522b\u4e0e\u6267\u884c\u7684\u662f____\u3002',
#   u'A\u300164MB',
#   u'B\u300164GB',
#   u'C\u300165.536MB',
#   u'D\u300165.536GB'],
#  [u'\u4e0b\u5217\u4e0d\u5c5e\u4e8e\u4f20\u64ad\u75c5\u6bd2\u7684\u8f7d\u4f53\u662f____\u3002',
#   u'A\u3001\u663e\u793a\u5668',
#   u'B\u3001\u8f6f\u76d8',
#   u'C\u3001\u786c\u76d8',
#   u'D\u3001\u7f51\u7edc'],
#  [u'\u73b0\u5728\u7f51\u4e0a\u6709\u4e2a\u6bd4\u8f83\u6d41\u884c\u7684\u8bcd\u53eb\u95ea\u5ba2\uff0c\u901a\u5e38\u7684\u628a\u4ec0\u4e48\u6837\u7684\u4eba\u53eb\u505a\u95ea\u5ba2____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u786c\u76d8',
#   u'D\u3001\u7f51\u7edc'],
#  [u'\u73b0\u5728\u7f51\u4e0a\u6709\u4e2a\u6bd4\u8f83\u6d41\u884c\u7684\u8bcd\u53eb\u95ea\u5ba2\uff0c\u901a\u5e38\u7684\u628a\u4ec0\u4e48\u6837\u7684\u4eba\u53eb\u505a\u95ea\u5ba2____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u64c5\u957f\u7528Flash\u5236\u4f5c\u52a8\u753b',
#   u'D\u3001\u64c5\u957f\u7528\u7535\u8111\u5199\u4f5c'],
#  [u'\u5728\u9009\u5b9a\u6587\u4ef6\u6216\u6587\u4ef6\u5939\u540e\uff0c\u5c06\u5176\u5f7b\u5e95\u5220\u9664\u7684\u64cd\u4f5c\u662f____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u64c5\u957f\u7528Flash\u5236\u4f5c\u52a8\u753b',
#   u'D\u3001\u64c5\u957f\u7528\u7535\u8111\u5199\u4f5c'],
#  [u'\u5728\u9009\u5b9a\u6587\u4ef6\u6216\u6587\u4ef6\u5939\u540e\uff0c\u5c06\u5176\u5f7b\u5e95\u5220\u9664\u7684\u64cd\u4f5c\u662f____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u64c5\u957f\u7528Flash\u5236\u4f5c\u52a8\u753b',
#   u'D\u3001\u64c5\u957f\u7528\u7535\u8111\u5199\u4f5c'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u64c5\u957f\u7528Flash\u5236\u4f5c\u52a8\u753b',
#   u'D\u3001\u64c5\u957f\u7528\u7535\u8111\u5199\u4f5c'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u64c5\u957f\u7528PhotoShop\u7ed8\u753b',
#   u'B\u3001\u64c5\u957f\u7528\u7535\u8111\u5236\u4f5c\u97f3\u4e50',
#   u'C\u3001\u64c5\u957f\u7528Flash\u5236\u4f5c\u52a8\u753b',
#   u'D\u3001\u64c5\u957f\u7528\u7535\u8111\u5199\u4f5c'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u6570\u636e\u5904\u7406',
#   u'B\u3001\u529e\u516c\u81ea\u52a8\u5316',
#   u'C\u3001\u8f85\u52a9\u6559\u5b66',
#   u'D\u3001\u591a\u5a92\u4f53\u6280\u672f'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u8ba1\u7b97\u673a\u7684\u4e2d\u592e\u5904\u7406\u5668',
#   u'B\u3001\u8ba1\u7b97\u5668',
#   u'C\u3001\u63a7\u5236\u5668',
#   u'D\u3001ALU'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u57df\u540d\u5230IP\u5730\u5740\u7684\u8f6c\u6362',
#   u'B\u3001IP\u5730\u5740\u5230\u57df\u540d\u7684\u8f6c\u6362',
#   u'C\u3001\u63a7\u5236\u5668',
#   u'D\u3001ALU'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u57df\u540d\u5230IP\u5730\u5740\u7684\u8f6c\u6362',
#   u'B\u3001IP\u5730\u5740\u5230\u57df\u540d\u7684\u8f6c\u6362',
#   u'C\u3001\u57df\u540d\u5230\u7269\u7406\u5730\u5740\u7684\u8f6c\u6362',
#   u'D\u3001\u7269\u7406\u5730\u5740\u5230\u57df\u540d\u7684\u8f6c\u6362'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u90ae\u4ef6',
#   u'B\u3001\u7535\u5b50\u516c\u544a\u7cfb\u7edf',
#   u'C\u3001\u6587\u4ef6\u4f20\u8f93',
#   u'D\u3001\u8fdc\u7a0b\u767b\u5f55\u7cfb\u7edf'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u7b7e\u540d',
#   u'B\u3001\u7535\u5b50\u5546\u52a1',
#   u'C\u3001\u7535\u5b50\u8d2d\u7269',
#   u'D\u3001\u7535\u5b50\u90ae\u4ef6'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u7b7e\u540d',
#   u'B\u3001\u7535\u5b50\u5546\u52a1',
#   u'C\u3001\u7535\u5b50\u8d2d\u7269',
#   u'D\u3001\u7535\u5b50\u90ae\u4ef6'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u7b7e\u540d',
#   u'B\u3001\u7535\u5b50\u5546\u52a1',
#   u'C\u3001\u7535\u5b50\u8d2d\u7269',
#   u'D\u3001\u7535\u5b50\u90ae\u4ef6'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7535\u5b50\u7b7e\u540d',
#   u'B\u3001\u7535\u5b50\u5546\u52a1',
#   u'C\u3001\u7535\u5b50\u8d2d\u7269',
#   u'D\u3001\u7535\u5b50\u90ae\u4ef6'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'C\u3001Inter',
#   u'Teacher',
#   u'D\u3001In',
#   u'Technology'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u8f6f\u4ef6',
#   u'B\u3001\u5fae\u5904\u7406\u5668',
#   u'C\u3001\u5b58\u50a8\u5668',
#   u'D\u3001\u78c1\u76d8\u7684\u5bb9\u91cf'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u8ba1\u7b97\u673a\u4e2d\u5149\u9a71\u7684\u54c1\u724c',
#   u'B\u3001\u8ba1\u7b97\u673a\u4e2dCPU\u7684\u578b\u53f7',
#   u'C\u3001\u5b58\u50a8\u5668',
#   u'D\u3001\u78c1\u76d8\u7684\u5bb9\u91cf'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u8ba1\u7b97\u673a\u4e2d\u5149\u9a71\u7684\u54c1\u724c',
#   u'B\u3001\u8ba1\u7b97\u673a\u4e2dCPU\u7684\u578b\u53f7',
#   u'C\u3001\u8ba1\u7b97\u673a\u4e2d\u7535\u6e90\u7684\u89c4\u683c',
#   u'D\u3001\u8ba1\u7b97\u673a\u4e2d\u7684\u5185\u5b58\u7684\u578b\u53f7'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u663e\u793a\u5668',
#   u'B\u3001\u5b58\u50a8\u5668',
#   u'C\u3001\u952e\u76d8',
#   u'D\u3001CPU'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u4e2d\u592e\u5904\u7406\u5668',
#   u'B\u3001\u968f\u673a\u5b58\u50a8\u5668',
#   u'C\u3001\u53ea\u8bfb\u5b58\u50a8\u5668',
#   u'D\u3001\u8f6f\u76d8'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7ed8\u56fe\u7a0b\u5e8f',
#   u'B\u3001\u89e3\u538b\u7a0b\u5e8f',
#   u'C\u3001\u5b89\u88c5\u7a0b\u5e8f',
#   u'D\u3001\u5378\u8f7d\u7a0b\u5e8f'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7ed8\u56fe\u7a0b\u5e8f',
#   u'B\u3001\u89e3\u538b\u7a0b\u5e8f',
#   u'C\u3001\u5b89\u88c5\u7a0b\u5e8f',
#   u'D\u3001\u5378\u8f7d\u7a0b\u5e8f'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7ed8\u56fe\u7a0b\u5e8f',
#   u'B\u3001\u89e3\u538b\u7a0b\u5e8f',
#   u'C\u3001\u5b89\u88c5\u7a0b\u5e8f',
#   u'D\u3001\u5378\u8f7d\u7a0b\u5e8f'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001URL',
#   u'B\u3001WWW',
#   u'C\u3001HTTP',
#   u'D\u3001USL'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u786c\u4ef6',
#   u'B\u3001\u786c\u4ef6\u7684\u63a5\u53e3',
#   u'C\u3001\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001\u5e94\u7528\u8f6f\u4ef6'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u7f16\u8f91',
#   u'B\u3001\u6392\u7248',
#   u'C\u3001\u6253\u5370',
#   u'D\u3001\u7f16\u8bd1'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u64cd\u4f5c\u7cfb\u7edf',
#   u'B\u3001\u901a\u7528\u5e94\u7528\u8f6f\u4ef6',
#   u'C\u3001\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001\u8bed\u8a00\u5904\u7406\u7a0b\u5e8f'],
#  [u'\u7528IE\u6d4f\u89c8\u5668\u6d4f\u89c8\u56e0\u7279\u7f51\u4fe1\u606f\u65f6\uff0c\u9ed8\u8ba4\u7684\u534f\u8bae\u662f____\u3002',
#   u'A\u3001\u64cd\u4f5c\u7cfb\u7edf',
#   u'B\u3001\u901a\u7528\u5e94\u7528\u8f6f\u4ef6',
#   u'C\u3001\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001\u8bed\u8a00\u5904\u7406\u7a0b\u5e8f'],
#  [u'\u534a\u5bfc\u4f53\u53ea\u8bfb\u5b58\u50a8\u5668\uff08ROM\uff09\u4e0e\u534a\u5bfc\u4f53\u968f\u673a\u5b58\u50a8\u5668\uff08RAM\uff09\u7684\u4e3b\u8981\u533a\u522b\u5728\u4e8e____\u3002',
#   u'A\u3001ROM',
#   u'\u53ef\u4ee5\u6c38\u4e45\u4fdd\u5b58\u4fe1\u606f\uff0cRAM\u5728\u6389\u7535\u540e\u4fe1\u606f\u4f1a\u4e22\u5931',
#   u'C\u3001\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001\u8bed\u8a00\u5904\u7406\u7a0b\u5e8f'],
#  [u'\u534a\u5bfc\u4f53\u53ea\u8bfb\u5b58\u50a8\u5668\uff08ROM\uff09\u4e0e\u534a\u5bfc\u4f53\u968f\u673a\u5b58\u50a8\u5668\uff08RAM\uff09\u7684\u4e3b\u8981\u533a\u522b\u5728\u4e8e____\u3002',
#   u'A\u3001ROM',
#   u'\u53ef\u4ee5\u6c38\u4e45\u4fdd\u5b58\u4fe1\u606f\uff0cRAM\u5728\u6389\u7535\u540e\u4fe1\u606f\u4f1a\u4e22\u5931',
#   u'C\u3001\u7cfb\u7edf\u8f6f\u4ef6',
#   u'D\u3001\u8bed\u8a00\u5904\u7406\u7a0b\u5e8f'],
#  [u'\u6bd4\u8f83\u5178\u578b\u7684\u538b\u7f29\u6587\u4ef6\u7c7b\u578b\u6709____\u3002',
#   u'A\u3001RAM',
#   u'B\u3001ZIP',
#   u'C\u3001WAV',
#   u'D\u3001HTML'],
#  [u'\u6bd4\u7279\uff08bit\uff09\u662f\u6570\u636e\u7684\u6700\u5c0f\u5355\u4f4d\uff0c\u4e00\u4e2a\u5b57\u8282\u6709\u51e0\u4e2a\u6bd4\u7279\u7ec4\u6210____\u3002',
#   u'A\u30012',
#   u'B\u30014',
#   u'C\u30018',
#   u'D\u300116'],
#  [u'\u6807\u51c6ASCII\u7801\u5171\u6709____\u79cd\u7f16\u7801\u3002',
#   u'A\u3001127',
#   u'B\u3001128',
#   u'C\u3001255',
#   u'D\u3001256'],
#  [u'\u6807\u51c6ASCII\u7801\u662f\u75287\u4f4d____\u4ee3\u7801\u6765\u8868\u793a\u7684\u3002',
#   u'A\u3001\u516b\u8fdb\u5236\u4ee3\u7801',
#   u'B\u3001\u5341\u8fdb\u5236\u4ee3\u7801',
#   u'C\u3001\u4e8c\u8fdb\u5236\u4ee3\u7801',
#   u'D\u3001\u5341\u516d\u8fdb\u5236\u4ee3\u7801'],
#  [u'\u6807\u51c6\u952e\u76d8\u7684\u56de\u8f66\u952e\u4e0a\u4e00\u822c\u90fd\u6807\u7740____\u3002',
#   u'A\u3001Shift',
#   u'B\u3001Enter',
#   u'C\u3001Tab',
#   u'D\u3001Backspace'],
#  [u'\u4e0d\u5c5e\u4e8e\u641c\u7d22\u5f15\u64ce\u7f51\u5740\u7684\u6709____\u3002',
#   u'A\u3001Shift',
#   u'B\u3001Enter',
#   u'C\u3001Tab',
#   u'D\u3001Backspace'],
#  ...]

# %%
os.remove('example.xls')
